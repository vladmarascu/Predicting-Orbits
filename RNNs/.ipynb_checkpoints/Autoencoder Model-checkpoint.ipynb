# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import tensorflow as tf
import os
from sklearn.metrics import mean_squared_error
import math
import warnings
warnings.filterwarnings("ignore")

# %%
# Load DataFrame and Libs

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import seaborn as sns
#sns.set_style('whitegrid')
plt.style.use("fivethirtyeight")
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM

df = pd.read_csv('Dataframes/3rdBodyPerturbationPoliastro.csv')
df_v = pd.read_csv('Dataframes/3rdBodyPerturbationPoliastro_vv.csv')

df['x_vv']=df_v.vv_x
df['y_vv']=df_v.vv_y
df['z_vv']=df_v.vv_z

df
# Out:
#                 x             y             z      x_vv      y_vv      z_vv
# 0    42159.783600      0.000000      0.000000  0.000000  3.074505  0.053666
# 1    39159.545914  15563.916303    266.913399 -1.142984  2.852848  0.048528
# 2    30572.229294  28909.053086    496.928223 -2.127756  2.228986  0.039518
# 3    17596.068412  38144.740319    671.356184 -2.813645  1.287415  0.027234
# 4     2068.446366  41949.706443    775.646554 -3.098444  0.161675  0.012698
# ..            ...           ...           ...       ...       ...       ...
# 995  38132.961517  21370.880108  -7532.333000 -0.876644  2.199413  1.750026
# 996  31399.515894  31233.289707   1828.575655 -1.692745  1.562118  1.820311
# 997  20906.077447  37238.565267  10967.804062 -2.312211  0.726117  1.664753
# 998   7871.245318  38575.122415  18731.818721 -2.661184 -0.221639  1.293445
# 999  -6142.526530  34919.272230  24066.202237 -2.681132 -1.179765  0.734721
#
# [1000 rows x 6 columns]

# %%
# Train-test split

train_size = int(len(df) * 0.8) 

train_df,test_df = df[1:train_size], df[train_size:]

# %%
test_df
# Out:
#                 x             y             z      x_vv      y_vv      z_vv
# 800 -38640.279625  -2764.935183  17604.980941 -0.242379 -2.869481 -1.032661
# 801 -37222.004154 -17134.306183  11135.984105  0.783117 -2.603604 -1.431914
# 802 -30699.416577 -29154.049729   3087.546466  1.701144 -1.974296 -1.633559
# 803 -19981.800403 -37148.488205  -5420.909441  2.380643 -1.071344 -1.607049
# 804  -6568.003292 -40025.406603 -13203.492438  2.729043 -0.025797 -1.357603
# ..            ...           ...           ...       ...       ...       ...
# 995  38132.961517  21370.880108  -7532.333000 -0.876644  2.199413  1.750026
# 996  31399.515894  31233.289707   1828.575655 -1.692745  1.562118  1.820311
# 997  20906.077447  37238.565267  10967.804062 -2.312211  0.726117  1.664753
# 998   7871.245318  38575.122415  18731.818721 -2.661184 -0.221639  1.293445
# 999  -6142.526530  34919.272230  24066.202237 -2.681132 -1.179765  0.734721
#
# [200 rows x 6 columns]

# %%
# Scaling

train = train_df
scalers={}
for i in train_df.columns:
    scaler = MinMaxScaler(feature_range=(-1,1))
    s_s = scaler.fit_transform(train[i].values.reshape(-1,1))
    s_s=np.reshape(s_s,len(s_s))
    scalers['scaler_'+ i] = scaler
    train[i]=s_s
test = test_df
for i in train_df.columns:
    scaler = scalers['scaler_'+i]
    s_s = scaler.transform(test[i].values.reshape(-1,1))
    s_s=np.reshape(s_s,len(s_s))
    scalers['scaler_'+i] = scaler
    test[i]=s_s

# %%
# Now we will make a function that will use a sliding window approach to transform our series into samples 
# of input past observations and output future observations to use supervised learning algorithms.

# FUNCTION
def split_series(series, n_past, n_future):
    # n_past ==> no of past observations
    # n_future ==> no of future observations 
    X, y = list(), list()
    for window_start in range(len(series)):
        past_end = window_start + n_past
        future_end = past_end + n_future
        if future_end > len(series):
            break
        # slicing the past and future parts of the window
        past, future = series[window_start:past_end, :], series[past_end:future_end, :]
        X.append(past)
        y.append(future)
    return np.array(X), np.array(y)

# %%
# Convert train and test data:

# Variables
n_past = 60
n_future = 136
n_features = 6

# CALLS
X_train, y_train = split_series(train.values, n_past, n_future)
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], n_features))
y_train = y_train.reshape((y_train.shape[0], y_train.shape[1], n_features))

X_test, y_test = split_series(test.values, n_past, n_future)
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], n_features))
y_test = y_test.reshape((y_test.shape[0], y_test.shape[1], n_features))

# %%
X_train.shape
# Out:
# (604, 60, 6)

# %%
X_test.shape
# Out:
# (5, 60, 6)

# %%
y_train.shape
# Out:
# (604, 136, 6)

# %%
y_test.shape
# Out:
# (5, 136, 6)

# %% [markdown]
# # Multivariate model

# %%
# Doesn't work like this but technically its the same as the stuff below (?) -- For simplicity look at this

# %% [raw]
# from keras.models import Sequential
# from keras.layers import Dense, LSTM, RepeatVector, TimeDistributed
#
# # Build the LSTM model
# # Note: replace LSTM with GRU or RNN if you want to try those
# model = Sequential()
# model.add(LSTM(128, input_shape=(n_past, n_features)))
# model.add(RepeatVector(n_future))
# model.add(LSTM(128, return_sequences=True))
# model.add(TimeDistributed(Dense(1)))
#
# # Compile the model
# model.compile(optimizer='adam', loss='huber')
#
# # Train the model
# history=model.fit(X_train, y_train, batch_size=256, epochs=100, validation_data=(X_test,y_test))
#
# # Plot Training Loss
# plt.plot(history.history['loss']) # add validation loss
# plt.title('model loss')
# plt.ylabel('period')
# plt.xlabel('epoch')
# plt.legend(['training'], loc='upper right')
# plt.show()

# %% [raw]
# pred = model.predict(X_test)
# pred.shape

# %% [markdown]
# # Sequence to Sequence Model with one encoder and one decoder layer.

# %%
# %%time

encoder_inputs = tf.keras.layers.Input(shape=(n_past, n_features))
encoder_l1 = tf.keras.layers.LSTM(128, return_state=True)
encoder_outputs1 = encoder_l1(encoder_inputs)
encoder_states1 = encoder_outputs1[1:]

decoder_inputs = tf.keras.layers.RepeatVector(n_future)(encoder_outputs1[0])
decoder_l1 = tf.keras.layers.LSTM(128, return_sequences=True)(decoder_inputs,initial_state = encoder_states1)
decoder_outputs1 = tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(n_features))(decoder_l1)

model = tf.keras.models.Model(encoder_inputs,decoder_outputs1)

model.compile(optimizer=tf.keras.optimizers.Adam(), loss = tf.keras.losses.Huber())

history = model.fit(
                    X_train, y_train, 
                    batch_size=256, 
                    epochs=250, 
                    validation_data=(X_test,y_test)
                   )

# Plot Training Loss
plt.figure(figsize=(16,8))
plt.plot(history.history['loss']) # add validation loss
plt.plot(history.history['val_loss']) # add validation loss
plt.title('Autoencoder model training losses', fontsize=18)
plt.ylabel('Loss', fontsize=18)
plt.xlabel('Epoch', fontsize=18)
plt.legend(['Loss','Validation Loss'], loc='upper right', fontsize=18)
plt.show()
# Out:
# Epoch 1/250
# 3/3 [==============================] - 2s 546ms/step - loss: 0.1828 - val_loss: 0.2349
# Epoch 2/250
# 3/3 [==============================] - 1s 254ms/step - loss: 0.1820 - val_loss: 0.2341
# Epoch 3/250
# 3/3 [==============================] - 1s 251ms/step - loss: 0.1812 - val_loss: 0.2337
# Epoch 4/250
# 3/3 [==============================] - 1s 248ms/step - loss: 0.1808 - val_loss: 0.2328
# Epoch 5/250
# 3/3 [==============================] - 1s 268ms/step - loss: 0.1801 - val_loss: 0.2321
# Epoch 6/250
# 3/3 [==============================] - 1s 259ms/step - loss: 0.1795 - val_loss: 0.2312
# Epoch 7/250
# 3/3 [==============================] - 1s 240ms/step - loss: 0.1786 - val_loss: 0.2296
# Epoch 8/250
# 3/3 [==============================] - 1s 272ms/step - loss: 0.1773 - val_loss: 0.2273
# Epoch 9/250
# 3/3 [==============================] - 1s 233ms/step - loss: 0.1750 - val_loss: 0.2230
# Epoch 10/250
# 3/3 [==============================] - 1s 266ms/step - loss: 0.1708 - val_loss: 0.2104
# Epoch 11/250
# 3/3 [==============================] - 1s 257ms/step - loss: 0.1574 - val_loss: 0.0771
# Epoch 12/250
# 3/3 [==============================] - 1s 266ms/step - loss: 0.1540 - val_loss: 0.2632
# Epoch 13/250
# 3/3 [==============================] - 1s 256ms/step - loss: 0.1356 - val_loss: 0.1470
# Epoch 14/250
# 3/3 [==============================] - 1s 267ms/step - loss: 0.0947 - val_loss: 0.0961
# Epoch 15/250
# 3/3 [==============================] - 1s 261ms/step - loss: 0.0377 - val_loss: 0.0600
# Epoch 16/250
# 3/3 [==============================] - 1s 259ms/step - loss: 0.0467 - val_loss: 0.0603
# Epoch 17/250
# 3/3 [==============================] - 1s 265ms/step - loss: 0.0227 - val_loss: 0.0516
# Epoch 18/250
# 3/3 [==============================] - 1s 265ms/step - loss: 0.0185 - val_loss: 0.0430
# Epoch 19/250
# 3/3 [==============================] - 1s 265ms/step - loss: 0.0171 - val_loss: 0.0343
# Epoch 20/250
# 3/3 [==============================] - 1s 272ms/step - loss: 0.0116 - val_loss: 0.0289
# Epoch 21/250
# 3/3 [==============================] - 1s 266ms/step - loss: 0.0116 - val_loss: 0.0287
# Epoch 22/250
# 3/3 [==============================] - 1s 282ms/step - loss: 0.0106 - val_loss: 0.0351
# Epoch 23/250
# 3/3 [==============================] - 1s 262ms/step - loss: 0.0084 - val_loss: 0.0339
# Epoch 24/250
# 3/3 [==============================] - 1s 257ms/step - loss: 0.0088 - val_loss: 0.0363
# Epoch 25/250
# 3/3 [==============================] - 1s 285ms/step - loss: 0.0086 - val_loss: 0.0351
# Epoch 26/250
# 3/3 [==============================] - 1s 258ms/step - loss: 0.0074 - val_loss: 0.0322
# Epoch 27/250
# 3/3 [==============================] - 1s 273ms/step - loss: 0.0074 - val_loss: 0.0318
# Epoch 28/250
# 3/3 [==============================] - 1s 278ms/step - loss: 0.0071 - val_loss: 0.0321
# Epoch 29/250
# 3/3 [==============================] - 1s 270ms/step - loss: 0.0068 - val_loss: 0.0329
# Epoch 30/250
# 3/3 [==============================] - 1s 283ms/step - loss: 0.0067 - val_loss: 0.0339
# Epoch 31/250
# 3/3 [==============================] - 1s 272ms/step - loss: 0.0067 - val_loss: 0.0323
# Epoch 32/250
# 3/3 [==============================] - 1s 285ms/step - loss: 0.0065 - val_loss: 0.0311
# Epoch 33/250
# 3/3 [==============================] - 1s 272ms/step - loss: 0.0064 - val_loss: 0.0308
# Epoch 34/250
# 3/3 [==============================] - 1s 291ms/step - loss: 0.0064 - val_loss: 0.0312
# Epoch 35/250
# 3/3 [==============================] - 2s 627ms/step - loss: 0.0064 - val_loss: 0.0307
# Epoch 36/250
# 3/3 [==============================] - 2s 519ms/step - loss: 0.0062 - val_loss: 0.0303
# Epoch 37/250
# 3/3 [==============================] - 1s 449ms/step - loss: 0.0062 - val_loss: 0.0295
# Epoch 38/250
# 3/3 [==============================] - 1s 426ms/step - loss: 0.0061 - val_loss: 0.0296
# Epoch 39/250
# 3/3 [==============================] - 1s 428ms/step - loss: 0.0062 - val_loss: 0.0295
# Epoch 40/250
# 3/3 [==============================] - 1s 398ms/step - loss: 0.0061 - val_loss: 0.0299
# Epoch 41/250
# 3/3 [==============================] - 1s 389ms/step - loss: 0.0061 - val_loss: 0.0302
# Epoch 42/250
# 3/3 [==============================] - 1s 378ms/step - loss: 0.0061 - val_loss: 0.0303
# Epoch 43/250
# 3/3 [==============================] - 1s 352ms/step - loss: 0.0060 - val_loss: 0.0303
# Epoch 44/250
# 3/3 [==============================] - 1s 352ms/step - loss: 0.0060 - val_loss: 0.0301
# Epoch 45/250
# 3/3 [==============================] - 1s 358ms/step - loss: 0.0060 - val_loss: 0.0298
# Epoch 46/250
# 3/3 [==============================] - 1s 330ms/step - loss: 0.0060 - val_loss: 0.0297
# Epoch 47/250
# 3/3 [==============================] - 1s 337ms/step - loss: 0.0059 - val_loss: 0.0296
# Epoch 48/250
# 3/3 [==============================] - 1s 330ms/step - loss: 0.0059 - val_loss: 0.0292
# Epoch 49/250
# 3/3 [==============================] - 1s 337ms/step - loss: 0.0059 - val_loss: 0.0292
# Epoch 50/250
# 3/3 [==============================] - 1s 334ms/step - loss: 0.0059 - val_loss: 0.0291
# Epoch 51/250
# 3/3 [==============================] - 1s 309ms/step - loss: 0.0058 - val_loss: 0.0290
# Epoch 52/250
# 3/3 [==============================] - 1s 324ms/step - loss: 0.0058 - val_loss: 0.0292
# Epoch 53/250
# 3/3 [==============================] - 1s 319ms/step - loss: 0.0058 - val_loss: 0.0291
# Epoch 54/250
# 3/3 [==============================] - 1s 311ms/step - loss: 0.0058 - val_loss: 0.0290
# Epoch 55/250
# 3/3 [==============================] - 1s 301ms/step - loss: 0.0057 - val_loss: 0.0288
# Epoch 56/250
# 3/3 [==============================] - 1s 314ms/step - loss: 0.0057 - val_loss: 0.0290
# Epoch 57/250
# 3/3 [==============================] - 1s 297ms/step - loss: 0.0057 - val_loss: 0.0289
# Epoch 58/250
# 3/3 [==============================] - 1s 297ms/step - loss: 0.0057 - val_loss: 0.0286
# Epoch 59/250
# 3/3 [==============================] - 1s 298ms/step - loss: 0.0056 - val_loss: 0.0284
# Epoch 60/250
# 3/3 [==============================] - 1s 300ms/step - loss: 0.0056 - val_loss: 0.0285
# Epoch 61/250
# 3/3 [==============================] - 1s 306ms/step - loss: 0.0056 - val_loss: 0.0284
# Epoch 62/250
# 3/3 [==============================] - 1s 288ms/step - loss: 0.0056 - val_loss: 0.0281
# Epoch 63/250
# 3/3 [==============================] - 1s 283ms/step - loss: 0.0056 - val_loss: 0.0280
# Epoch 64/250
# 3/3 [==============================] - 1s 289ms/step - loss: 0.0056 - val_loss: 0.0280
# Epoch 65/250
# 3/3 [==============================] - 1s 288ms/step - loss: 0.0056 - val_loss: 0.0279
# Epoch 66/250
# 3/3 [==============================] - 1s 275ms/step - loss: 0.0056 - val_loss: 0.0279
# Epoch 67/250
# 3/3 [==============================] - 1s 337ms/step - loss: 0.0056 - val_loss: 0.0279
# Epoch 68/250
# 3/3 [==============================] - 1s 370ms/step - loss: 0.0056 - val_loss: 0.0278
# Epoch 69/250
# 3/3 [==============================] - 1s 392ms/step - loss: 0.0055 - val_loss: 0.0278
# Epoch 70/250
# 3/3 [==============================] - 1s 343ms/step - loss: 0.0055 - val_loss: 0.0279
# Epoch 71/250
# 3/3 [==============================] - 1s 342ms/step - loss: 0.0054 - val_loss: 0.0279
# Epoch 72/250
# 3/3 [==============================] - 1s 322ms/step - loss: 0.0054 - val_loss: 0.0276
# Epoch 73/250
# 3/3 [==============================] - 1s 302ms/step - loss: 0.0053 - val_loss: 0.0273
# Epoch 74/250
# 3/3 [==============================] - 1s 324ms/step - loss: 0.0053 - val_loss: 0.0270
# Epoch 75/250
# 3/3 [==============================] - 1s 313ms/step - loss: 0.0054 - val_loss: 0.0265
# Epoch 76/250
# 3/3 [==============================] - 1s 316ms/step - loss: 0.0052 - val_loss: 0.0261
# Epoch 77/250
# 3/3 [==============================] - 1s 304ms/step - loss: 0.0052 - val_loss: 0.0260
# Epoch 78/250
# 3/3 [==============================] - 1s 302ms/step - loss: 0.0052 - val_loss: 0.0262
# Epoch 79/250
# 3/3 [==============================] - 1s 324ms/step - loss: 0.0053 - val_loss: 0.0261
# Epoch 80/250
# 3/3 [==============================] - 1s 326ms/step - loss: 0.0050 - val_loss: 0.0260
# Epoch 81/250
# 3/3 [==============================] - 1s 312ms/step - loss: 0.0050 - val_loss: 0.0260
# Epoch 82/250
# 3/3 [==============================] - 1s 297ms/step - loss: 0.0049 - val_loss: 0.0257
# Epoch 83/250
# 3/3 [==============================] - 1s 294ms/step - loss: 0.0048 - val_loss: 0.0254
# Epoch 84/250
# 3/3 [==============================] - 1s 287ms/step - loss: 0.0047 - val_loss: 0.0238
# Epoch 85/250
# 3/3 [==============================] - 1s 284ms/step - loss: 0.0045 - val_loss: 0.0224
# Epoch 86/250
# 3/3 [==============================] - 1s 282ms/step - loss: 0.0043 - val_loss: 0.0212
# Epoch 87/250
# 3/3 [==============================] - 1s 300ms/step - loss: 0.0044 - val_loss: 0.0197
# Epoch 88/250
# 3/3 [==============================] - 1s 305ms/step - loss: 0.0038 - val_loss: 0.0190
# Epoch 89/250
# 3/3 [==============================] - 1s 300ms/step - loss: 0.0043 - val_loss: 0.0150
# Epoch 90/250
# 3/3 [==============================] - 1s 328ms/step - loss: 0.0031 - val_loss: 0.0128
# Epoch 91/250
# 3/3 [==============================] - 1s 326ms/step - loss: 0.0029 - val_loss: 0.0120
# Epoch 92/250
# 3/3 [==============================] - 1s 339ms/step - loss: 0.0026 - val_loss: 0.0114
# Epoch 93/250
# 3/3 [==============================] - 1s 319ms/step - loss: 0.0025 - val_loss: 0.0100
# Epoch 94/250
# 3/3 [==============================] - 1s 327ms/step - loss: 0.0030 - val_loss: 0.0108
# Epoch 95/250
# 3/3 [==============================] - 1s 333ms/step - loss: 0.0027 - val_loss: 0.0089
# Epoch 96/250
# 3/3 [==============================] - 1s 310ms/step - loss: 0.0022 - val_loss: 0.0089
# Epoch 97/250
# 3/3 [==============================] - 1s 362ms/step - loss: 0.0026 - val_loss: 0.0108
# Epoch 98/250
# 3/3 [==============================] - 1s 345ms/step - loss: 0.0020 - val_loss: 0.0102
# Epoch 99/250
# 3/3 [==============================] - 1s 346ms/step - loss: 0.0021 - val_loss: 0.0091
# Epoch 100/250
# 3/3 [==============================] - 1s 344ms/step - loss: 0.0021 - val_loss: 0.0099
# Epoch 101/250
# 3/3 [==============================] - 1s 338ms/step - loss: 0.0019 - val_loss: 0.0087
# Epoch 102/250
# 3/3 [==============================] - 1s 347ms/step - loss: 0.0017 - val_loss: 0.0083
# Epoch 103/250
# 3/3 [==============================] - 1s 330ms/step - loss: 0.0017 - val_loss: 0.0086
# Epoch 104/250
# 3/3 [==============================] - 1s 325ms/step - loss: 0.0017 - val_loss: 0.0087
# Epoch 105/250
# 3/3 [==============================] - 1s 313ms/step - loss: 0.0017 - val_loss: 0.0082
# Epoch 106/250
# 3/3 [==============================] - 1s 336ms/step - loss: 0.0023 - val_loss: 0.0110
# Epoch 107/250
# 3/3 [==============================] - 1s 320ms/step - loss: 0.0026 - val_loss: 0.0082
# Epoch 108/250
# 3/3 [==============================] - 1s 329ms/step - loss: 0.0019 - val_loss: 0.0091
# Epoch 109/250
# 3/3 [==============================] - 1s 341ms/step - loss: 0.0021 - val_loss: 0.0078
# Epoch 110/250
# 3/3 [==============================] - 1s 321ms/step - loss: 0.0025 - val_loss: 0.0086
# Epoch 111/250
# 3/3 [==============================] - 1s 328ms/step - loss: 0.0023 - val_loss: 0.0075
# Epoch 112/250
# 3/3 [==============================] - 1s 338ms/step - loss: 0.0025 - val_loss: 0.0090
# Epoch 113/250
# 3/3 [==============================] - 1s 329ms/step - loss: 0.0022 - val_loss: 0.0082
# Epoch 114/250
# 3/3 [==============================] - 1s 327ms/step - loss: 0.0018 - val_loss: 0.0101
# Epoch 115/250
# 3/3 [==============================] - 1s 314ms/step - loss: 0.0049 - val_loss: 0.0176
# Epoch 116/250
# 3/3 [==============================] - 1s 346ms/step - loss: 0.0035 - val_loss: 0.0095
# Epoch 117/250
# 3/3 [==============================] - 1s 339ms/step - loss: 0.0037 - val_loss: 0.0070
# Epoch 118/250
# 3/3 [==============================] - 1s 332ms/step - loss: 0.0027 - val_loss: 0.0069
# Epoch 119/250
# 3/3 [==============================] - 1s 325ms/step - loss: 0.0025 - val_loss: 0.0071
# Epoch 120/250
# 3/3 [==============================] - 1s 316ms/step - loss: 0.0017 - val_loss: 0.0094
# Epoch 121/250
# 3/3 [==============================] - 1s 324ms/step - loss: 0.0022 - val_loss: 0.0065
# Epoch 122/250
# 3/3 [==============================] - 1s 326ms/step - loss: 0.0016 - val_loss: 0.0061
# Epoch 123/250
# 3/3 [==============================] - 1s 327ms/step - loss: 0.0021 - val_loss: 0.0067
# Epoch 124/250
# 3/3 [==============================] - 1s 328ms/step - loss: 0.0016 - val_loss: 0.0085
# Epoch 125/250
# 3/3 [==============================] - 1s 388ms/step - loss: 0.0022 - val_loss: 0.0058
# Epoch 126/250
# 3/3 [==============================] - 1s 366ms/step - loss: 0.0015 - val_loss: 0.0056
# Epoch 127/250
# 3/3 [==============================] - 1s 363ms/step - loss: 0.0018 - val_loss: 0.0070
# Epoch 128/250
# 3/3 [==============================] - 1s 363ms/step - loss: 0.0015 - val_loss: 0.0058
# Epoch 129/250
# 3/3 [==============================] - 1s 347ms/step - loss: 0.0014 - val_loss: 0.0058
# Epoch 130/250
# 3/3 [==============================] - 1s 354ms/step - loss: 0.0013 - val_loss: 0.0057
# Epoch 131/250
# 3/3 [==============================] - 1s 337ms/step - loss: 0.0013 - val_loss: 0.0056
# Epoch 132/250
# 3/3 [==============================] - 1s 343ms/step - loss: 0.0013 - val_loss: 0.0067
# Epoch 133/250
# 3/3 [==============================] - 1s 321ms/step - loss: 0.0015 - val_loss: 0.0054
# Epoch 134/250
# 3/3 [==============================] - 1s 356ms/step - loss: 0.0013 - val_loss: 0.0052
# Epoch 135/250
# 3/3 [==============================] - 1s 358ms/step - loss: 0.0013 - val_loss: 0.0060
# Epoch 136/250
# 3/3 [==============================] - 1s 351ms/step - loss: 0.0013 - val_loss: 0.0051
# Epoch 137/250
# 3/3 [==============================] - 1s 348ms/step - loss: 0.0013 - val_loss: 0.0052
# Epoch 138/250
# 3/3 [==============================] - 1s 334ms/step - loss: 0.0013 - val_loss: 0.0061
# Epoch 139/250
# 3/3 [==============================] - 1s 340ms/step - loss: 0.0016 - val_loss: 0.0049
# Epoch 140/250
# 3/3 [==============================] - 1s 339ms/step - loss: 0.0013 - val_loss: 0.0049
# Epoch 141/250
# 3/3 [==============================] - 1s 328ms/step - loss: 0.0020 - val_loss: 0.0125
# Epoch 142/250
# 3/3 [==============================] - 1s 331ms/step - loss: 0.0036 - val_loss: 0.0051
# Epoch 143/250
# 3/3 [==============================] - 1s 324ms/step - loss: 0.0017 - val_loss: 0.0053
# Epoch 144/250
# 3/3 [==============================] - 1s 342ms/step - loss: 0.0053 - val_loss: 0.0066
# Epoch 145/250
# 3/3 [==============================] - 1s 334ms/step - loss: 0.0021 - val_loss: 0.0103
# Epoch 146/250
# 3/3 [==============================] - 1s 343ms/step - loss: 0.0033 - val_loss: 0.0057
# Epoch 147/250
# 3/3 [==============================] - 1s 334ms/step - loss: 0.0016 - val_loss: 0.0044
# Epoch 148/250
# 3/3 [==============================] - 1s 336ms/step - loss: 0.0015 - val_loss: 0.0046
# Epoch 149/250
# 3/3 [==============================] - 1s 331ms/step - loss: 0.0017 - val_loss: 0.0053
# Epoch 150/250
# 3/3 [==============================] - 1s 329ms/step - loss: 0.0013 - val_loss: 0.0050
# Epoch 151/250
# 3/3 [==============================] - 1s 335ms/step - loss: 0.0013 - val_loss: 0.0063
# Epoch 152/250
# 3/3 [==============================] - 1s 325ms/step - loss: 0.0015 - val_loss: 0.0046
# Epoch 153/250
# 3/3 [==============================] - 1s 303ms/step - loss: 0.0014 - val_loss: 0.0044
# Epoch 154/250
# 3/3 [==============================] - 1s 346ms/step - loss: 0.0020 - val_loss: 0.0042
# Epoch 155/250
# 3/3 [==============================] - 1s 349ms/step - loss: 0.0015 - val_loss: 0.0077
# Epoch 156/250
# 3/3 [==============================] - 1s 375ms/step - loss: 0.0017 - val_loss: 0.0059
# Epoch 157/250
# 3/3 [==============================] - 1s 343ms/step - loss: 0.0014 - val_loss: 0.0043
# Epoch 158/250
# 3/3 [==============================] - 1s 369ms/step - loss: 0.0013 - val_loss: 0.0043
# Epoch 159/250
# 3/3 [==============================] - 1s 371ms/step - loss: 0.0016 - val_loss: 0.0066
# Epoch 160/250
# 3/3 [==============================] - 1s 325ms/step - loss: 0.0014 - val_loss: 0.0057
# Epoch 161/250
# 3/3 [==============================] - 1s 319ms/step - loss: 0.0016 - val_loss: 0.0042
# Epoch 162/250
# 3/3 [==============================] - 1s 327ms/step - loss: 0.0015 - val_loss: 0.0044
# Epoch 163/250
# 3/3 [==============================] - 1s 309ms/step - loss: 0.0013 - val_loss: 0.0058
# Epoch 164/250
# 3/3 [==============================] - 1s 322ms/step - loss: 0.0018 - val_loss: 0.0044
# Epoch 165/250
# 3/3 [==============================] - 1s 323ms/step - loss: 0.0014 - val_loss: 0.0047
# Epoch 166/250
# 3/3 [==============================] - 1s 329ms/step - loss: 0.0021 - val_loss: 0.0047
# Epoch 167/250
# 3/3 [==============================] - 1s 320ms/step - loss: 0.0012 - val_loss: 0.0065
# Epoch 168/250
# 3/3 [==============================] - 1s 333ms/step - loss: 0.0015 - val_loss: 0.0041
# Epoch 169/250
# 3/3 [==============================] - 1s 335ms/step - loss: 0.0012 - val_loss: 0.0039
# Epoch 170/250
# 3/3 [==============================] - 1s 340ms/step - loss: 0.0014 - val_loss: 0.0040
# Epoch 171/250
# 3/3 [==============================] - 1s 338ms/step - loss: 0.0012 - val_loss: 0.0057
# Epoch 172/250
# 3/3 [==============================] - 1s 366ms/step - loss: 0.0014 - val_loss: 0.0040
# Epoch 173/250
# 3/3 [==============================] - 1s 340ms/step - loss: 0.0011 - val_loss: 0.0040
# Epoch 174/250
# 3/3 [==============================] - 1s 341ms/step - loss: 0.0013 - val_loss: 0.0044
# Epoch 175/250
# 3/3 [==============================] - 1s 346ms/step - loss: 0.0012 - val_loss: 0.0053
# Epoch 176/250
# 3/3 [==============================] - 1s 354ms/step - loss: 0.0014 - val_loss: 0.0040
# Epoch 177/250
# 3/3 [==============================] - 1s 367ms/step - loss: 0.0013 - val_loss: 0.0046
# Epoch 178/250
# 3/3 [==============================] - 1s 472ms/step - loss: 0.0011 - val_loss: 0.0058
# Epoch 179/250
# 3/3 [==============================] - 1s 470ms/step - loss: 0.0016 - val_loss: 0.0041
# Epoch 180/250
# 3/3 [==============================] - 1s 434ms/step - loss: 0.0014 - val_loss: 0.0043
# Epoch 181/250
# 3/3 [==============================] - 1s 492ms/step - loss: 0.0011 - val_loss: 0.0048
# Epoch 182/250
# 3/3 [==============================] - 1s 391ms/step - loss: 0.0012 - val_loss: 0.0039
# Epoch 183/250
# 3/3 [==============================] - 1s 379ms/step - loss: 0.0012 - val_loss: 0.0060
# Epoch 184/250
# 3/3 [==============================] - 1s 370ms/step - loss: 0.0012 - val_loss: 0.0040
# Epoch 185/250
# 3/3 [==============================] - 1s 362ms/step - loss: 0.0011 - val_loss: 0.0041
# Epoch 186/250
# 3/3 [==============================] - 1s 358ms/step - loss: 0.0013 - val_loss: 0.0083
# Epoch 187/250
# 3/3 [==============================] - 1s 345ms/step - loss: 0.0024 - val_loss: 0.0043
# Epoch 188/250
# 3/3 [==============================] - 1s 358ms/step - loss: 0.0017 - val_loss: 0.0043
# Epoch 189/250
# 3/3 [==============================] - 1s 343ms/step - loss: 0.0011 - val_loss: 0.0041
# Epoch 190/250
# 3/3 [==============================] - 1s 343ms/step - loss: 0.0012 - val_loss: 0.0069
# Epoch 191/250
# 3/3 [==============================] - 1s 338ms/step - loss: 0.0037 - val_loss: 0.0045
# Epoch 192/250
# 3/3 [==============================] - 1s 331ms/step - loss: 0.0031 - val_loss: 0.0097
# Epoch 193/250
# 3/3 [==============================] - 1s 329ms/step - loss: 0.0053 - val_loss: 0.0118
# Epoch 194/250
# 3/3 [==============================] - 1s 334ms/step - loss: 0.0025 - val_loss: 0.0114
# Epoch 195/250
# 3/3 [==============================] - 1s 333ms/step - loss: 0.0054 - val_loss: 0.0039
# Epoch 196/250
# 3/3 [==============================] - 1s 323ms/step - loss: 0.0019 - val_loss: 0.0057
# Epoch 197/250
# 3/3 [==============================] - 1s 315ms/step - loss: 0.0033 - val_loss: 0.0050
# Epoch 198/250
# 3/3 [==============================] - 1s 309ms/step - loss: 0.0016 - val_loss: 0.0066
# Epoch 199/250
# 3/3 [==============================] - 1s 343ms/step - loss: 0.0016 - val_loss: 0.0067
# Epoch 200/250
# 3/3 [==============================] - 1s 328ms/step - loss: 0.0017 - val_loss: 0.0044
# Epoch 201/250
# 3/3 [==============================] - 1s 333ms/step - loss: 0.0011 - val_loss: 0.0046
# Epoch 202/250
# 3/3 [==============================] - 1s 324ms/step - loss: 0.0011 - val_loss: 0.0047
# Epoch 203/250
# 3/3 [==============================] - 1s 321ms/step - loss: 0.0011 - val_loss: 0.0042
# Epoch 204/250
# 3/3 [==============================] - 1s 314ms/step - loss: 0.0011 - val_loss: 0.0052
# Epoch 205/250
# 3/3 [==============================] - 1s 314ms/step - loss: 0.0011 - val_loss: 0.0044
# Epoch 206/250
# 3/3 [==============================] - 1s 314ms/step - loss: 0.0011 - val_loss: 0.0062
# Epoch 207/250
# 3/3 [==============================] - 1s 318ms/step - loss: 0.0011 - val_loss: 0.0043
# Epoch 208/250
# 3/3 [==============================] - 1s 319ms/step - loss: 0.0010 - val_loss: 0.0049
# Epoch 209/250
# 3/3 [==============================] - 1s 331ms/step - loss: 0.0010 - val_loss: 0.0042
# Epoch 210/250
# 3/3 [==============================] - 1s 328ms/step - loss: 0.0010 - val_loss: 0.0050
# Epoch 211/250
# 3/3 [==============================] - 1s 329ms/step - loss: 0.0010 - val_loss: 0.0047
# Epoch 212/250
# 3/3 [==============================] - 1s 323ms/step - loss: 0.0010 - val_loss: 0.0049
# Epoch 213/250
# 3/3 [==============================] - 1s 324ms/step - loss: 0.0010 - val_loss: 0.0046
# Epoch 214/250
# 3/3 [==============================] - 1s 320ms/step - loss: 0.0010 - val_loss: 0.0047
# Epoch 215/250
# 3/3 [==============================] - 1s 345ms/step - loss: 0.0010 - val_loss: 0.0042
# Epoch 216/250
# 3/3 [==============================] - 1s 338ms/step - loss: 0.0011 - val_loss: 0.0049
# Epoch 217/250
# 3/3 [==============================] - 1s 329ms/step - loss: 0.0010 - val_loss: 0.0055
# Epoch 218/250
# 3/3 [==============================] - 1s 345ms/step - loss: 0.0012 - val_loss: 0.0044
# Epoch 219/250
# 3/3 [==============================] - 1s 329ms/step - loss: 0.0010 - val_loss: 0.0043
# Epoch 220/250
# 3/3 [==============================] - 1s 323ms/step - loss: 9.8438e-04 - val_loss: 0.0044
# Epoch 221/250
# 3/3 [==============================] - 1s 328ms/step - loss: 0.0013 - val_loss: 0.0061
# Epoch 222/250
# 3/3 [==============================] - 1s 340ms/step - loss: 0.0015 - val_loss: 0.0056
# Epoch 223/250
# 3/3 [==============================] - 1s 394ms/step - loss: 0.0010 - val_loss: 0.0045
# Epoch 224/250
# 3/3 [==============================] - 1s 325ms/step - loss: 0.0013 - val_loss: 0.0061
# Epoch 225/250
# 3/3 [==============================] - 1s 342ms/step - loss: 0.0011 - val_loss: 0.0050
# Epoch 226/250
# 3/3 [==============================] - 1s 354ms/step - loss: 0.0010 - val_loss: 0.0045
# Epoch 227/250
# 3/3 [==============================] - 1s 343ms/step - loss: 0.0011 - val_loss: 0.0056
# Epoch 228/250
# 3/3 [==============================] - 1s 355ms/step - loss: 0.0011 - val_loss: 0.0047
# Epoch 229/250
# 3/3 [==============================] - 1s 337ms/step - loss: 9.6021e-04 - val_loss: 0.0046
# Epoch 230/250
# 3/3 [==============================] - 1s 351ms/step - loss: 9.7079e-04 - val_loss: 0.0065
# Epoch 231/250
# 3/3 [==============================] - 1s 362ms/step - loss: 0.0013 - val_loss: 0.0046
# Epoch 232/250
# 3/3 [==============================] - 1s 391ms/step - loss: 0.0013 - val_loss: 0.0054
# Epoch 233/250
# 3/3 [==============================] - 1s 395ms/step - loss: 9.8819e-04 - val_loss: 0.0063
# Epoch 234/250
# 3/3 [==============================] - 1s 336ms/step - loss: 0.0016 - val_loss: 0.0052
# Epoch 235/250
# 3/3 [==============================] - 1s 326ms/step - loss: 0.0018 - val_loss: 0.0065
# Epoch 236/250
# 3/3 [==============================] - 1s 345ms/step - loss: 0.0011 - val_loss: 0.0070
# Epoch 237/250
# 3/3 [==============================] - 1s 335ms/step - loss: 0.0021 - val_loss: 0.0048
# Epoch 238/250
# 3/3 [==============================] - 1s 338ms/step - loss: 0.0021 - val_loss: 0.0046
# Epoch 239/250
# 3/3 [==============================] - 1s 345ms/step - loss: 0.0017 - val_loss: 0.0132
# Epoch 240/250
# 3/3 [==============================] - 1s 354ms/step - loss: 0.0048 - val_loss: 0.0051
# Epoch 241/250
# 3/3 [==============================] - 1s 339ms/step - loss: 0.0018 - val_loss: 0.0047
# Epoch 242/250
# 3/3 [==============================] - 1s 349ms/step - loss: 0.0023 - val_loss: 0.0092
# Epoch 243/250
# 3/3 [==============================] - 1s 348ms/step - loss: 0.0013 - val_loss: 0.0055
# Epoch 244/250
# 3/3 [==============================] - 1s 328ms/step - loss: 0.0015 - val_loss: 0.0050
# Epoch 245/250
# 3/3 [==============================] - 1s 336ms/step - loss: 0.0013 - val_loss: 0.0052
# Epoch 246/250
# 3/3 [==============================] - 1s 336ms/step - loss: 0.0013 - val_loss: 0.0058
# Epoch 247/250
# 3/3 [==============================] - 1s 459ms/step - loss: 0.0013 - val_loss: 0.0089
# Epoch 248/250
# 3/3 [==============================] - 1s 427ms/step - loss: 0.0017 - val_loss: 0.0048
# Epoch 249/250
# 3/3 [==============================] - 1s 403ms/step - loss: 0.0016 - val_loss: 0.0053
# Epoch 250/250
# 3/3 [==============================] - 1s 410ms/step - loss: 0.0011 - val_loss: 0.0076
# Wall time: 6min 52s

# %%
pred = model.predict(X_test)
pred.shape
# Out:
# (5, 136, 6)

# %%
for index,i in enumerate(train_df.columns):
    scaler = scalers['scaler_'+i]
    pred[:,:,index]=scaler.inverse_transform(pred[:,:,index])
    #y_train[:,:,index]=scaler.inverse_transform(y_train[:,:,index])
    y_test[:,:,index]=scaler.inverse_transform(y_test[:,:,index])
y_test.shape
# Out:
# (5, 136, 6)

# %% [markdown]
# Pred vs test of Feature 0 (x):

# %%
y_test[0,:,0]
# Out:
# array([ 36469.11006238,  29881.87362072,  19126.08641357,   5668.28662176,
#         -8580.68636836, -21580.77033154, -31508.40559114, -37025.09594659,
#        -37423.65401184, -32679.21080377, -23442.55060601, -10978.72035769,
#          2985.7054782 ,  16520.84509467,  27798.55840532,  35344.6529504 ,
#         38188.59658665,  35937.84933107,  28822.74069404,  17720.63777403,
#          4114.25199323, -10076.80861617, -22801.97239595, -32242.02806097,
#        -37102.74134816, -36769.24757745, -31336.97455908, -21571.53138319,
#         -8818.30767242,   5160.81489587,  18443.01905644,  29245.27551094,
#         36173.05174199,  38358.08582002,  35508.90974646,  27930.06425218,
#         16532.92597256,   2803.99330865, -11337.25085958, -23827.15132184,
#        -32834.79545718, -37090.67245283, -36060.64730559, -29961.60688874,
#        -19682.2591247 ,  -6654.86141998,   7325.09001583,  20349.69801356,
#         30687.39019716,  37022.46297369,  38582.7040899 ,  35170.55413207,
#         27159.65660567,  15491.25244685,   1649.62778429, -12452.37006549,
#        -24737.71141331, -33350.77554458, -37028.69713781, -35308.17355376,
#        -28532.91935015, -17728.54239601,  -4426.28091299,   9543.24348593,
#         22294.85496956,  32156.87124941,  37894.81342405,  38828.52610245,
#         34851.03435358,  26405.33305052,  14466.34054544,    517.42857641,
#        -13539.88205554, -25619.72478396, -33838.60403712, -36927.9100756 ,
#        -34489.60482525, -27001.73448062, -15644.79923912,  -2063.37073903,
#         11873.26032806,  24311.13151006,  33650.89771167,  38746.23568099,
#         39010.58053471,  34427.90365417,  25516.64921786,  13295.13031848,
#          -746.5769663 , -14720.80277592, -26546.1768939 , -34320.64602694,
#        -36771.32526512, -33562.55461185, -25314.78073976, -13378.36531582,
#           475.29130877,  14335.91691174,  26389.87912069,  35125.07291216,
#         39495.89966243,  39015.67441762,  33764.50643583,  24344.91238622,
#         11831.95399561,  -2267.16755835, -16081.65013268, -27554.21814001,
#        -34791.90830008, -36531.1656519 , -32500.5622256 , -23462.34321955,
#        -10942.64330403,   3154.32217645,  16877.11788193,  28460.65160328,
#         36494.1269554 ,  40046.84327523,  38741.77660214,  32762.22012687,
#         22803.73716024,  10009.9411011 ,  -4086.0420777 , -17635.30604664,
#        -28631.54042649, -35228.94677626, -36200.39125888, -31337.15373535,
#        -21527.83703048,  -8462.17081187,   5826.95157195,  19347.86748109,
#         30387.40542448,  37643.90463917,  40311.82768611,  38132.9615171 ])

# %%
pred[0,:,0]
# Out:
# array([ 3.8770828e+04,  3.1287916e+04,  1.9748990e+04,  5.6890435e+03,
#        -8.9388857e+03, -2.1989885e+04, -3.1548051e+04, -3.6353629e+04,
#        -3.5980852e+04, -3.0674500e+04, -2.1085311e+04, -8.2622070e+03,
#         6.1500171e+03,  1.9939035e+04,  3.0861789e+04,  3.7362785e+04,
#         3.8868574e+04,  3.5544902e+04,  2.7886160e+04,  1.6608066e+04,
#         2.9249622e+03, -1.1314255e+04, -2.3949299e+04, -3.3045977e+04,
#        -3.7345727e+04, -3.6441707e+04, -3.0615787e+04, -2.0584703e+04,
#        -7.4886367e+03,  6.9558008e+03,  2.0536078e+04,  3.1087785e+04,
#         3.7163738e+04,  3.8270930e+04,  3.4606867e+04,  2.6670410e+04,
#         1.5201098e+04,  1.4680574e+03, -1.2634285e+04, -2.4945119e+04,
#        -3.3579359e+04, -3.7358539e+04, -3.5951566e+04, -2.9688301e+04,
#        -1.9321586e+04, -6.0420991e+03,  8.3766230e+03,  2.1702844e+04,
#         3.1824596e+04,  3.7392453e+04,  3.7999207e+04,  3.3885016e+04,
#         2.5565961e+04,  1.3820230e+04, -1.6887547e+01, -1.4004438e+04,
#        -2.5988965e+04, -3.4144758e+04, -3.7381207e+04, -3.5447191e+04,
#        -2.8722973e+04, -1.8000672e+04, -4.5261050e+03,  9.8666387e+03,
#         2.2927777e+04,  3.2603027e+04,  3.7645035e+04,  3.7733449e+04,
#         3.3150465e+04,  2.4431451e+04,  1.2399019e+04, -1.5415245e+03,
#        -1.5403932e+04, -2.7046271e+04, -3.4707105e+04, -3.7387055e+04,
#        -3.4915328e+04, -2.7722381e+04, -1.6641965e+04, -2.9785530e+03,
#         1.1372960e+04,  2.4150316e+04,  3.3363930e+04,  3.7871047e+04,
#         3.7435941e+04,  3.2380076e+04,  2.3259432e+04,  1.0946003e+04,
#        -3.0834424e+03, -1.6801086e+04, -2.8082125e+04, -3.5234070e+04,
#        -3.7350547e+04, -3.4339473e+04, -2.6679990e+04, -1.5249292e+04,
#        -1.4130112e+03,  1.2874729e+04,  2.5346457e+04,  3.4084414e+04,
#         3.8051566e+04,  3.7093184e+04,  3.1566340e+04,  2.2049227e+04,
#         9.4676904e+03, -4.6300420e+03, -1.8179658e+04, -2.9079604e+04,
#        -3.5710781e+04, -3.7260586e+04, -3.3712984e+04, -2.5593961e+04,
#        -1.3825817e+04,  1.6266914e+02,  1.4360975e+04,  2.6504570e+04,
#         3.4754238e+04,  3.8178773e+04,  3.6699902e+04,  3.0706803e+04,
#         2.0801773e+04,  7.9686553e+03, -6.1739224e+03, -1.9530967e+04,
#        -3.0030387e+04, -3.6130570e+04, -3.7112746e+04, -3.3033668e+04,
#        -2.4464486e+04, -1.2374411e+04,  1.7432036e+03,  1.5825154e+04,
#         2.7618490e+04,  3.5368668e+04,  3.8249496e+04,  3.6254312e+04],
#       dtype=float32)

# %% [markdown]
# ## Visualizations:

# %%
dictt = {
    0: "x",
    1: "y",
    2: 'z',
    3: 'x_velocity',
    4: 'y_velocity',
    5: 'z_velocity',
}

# %%
for i in range(0,6):
    print(i)
    dataa = {'testY': y_test[0,:,i], 'predictions': pred[0,:,i]}
    dff = pd.DataFrame.from_dict(dataa)
    
    plt.figure(figsize=(16,8))
    plt.title(f'Predicted vs. Test data for feature {dictt[i]}', fontsize=18)
    plt.xlabel('Step', fontsize=18)
    plt.ylabel('Coordinate [km]', fontsize=18)
    plt.plot(list(range(864,1000)), dff.testY)
    plt.plot(list(range(864,1000)), dff.predictions)
    plt.legend(['Test', 'Prediction'], loc='lower left', fontsize=18)
    plt.show()
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %% [raw]
# # RMSE
#
# for index,i in enumerate(train_df.columns):
#     #print(index)
#     print('Feature: '+str(i))
#     for j in range(0,n_future):
#         print("Step <",j,"> RMSE: ",math.sqrt(mean_squared_error(y_test[:,j-1,index],pred[:,j-1,index])))
#         print()

# %% [markdown]
# ## RMSE:

# %% [raw]
# # Mean RMSE
# from statistics import mean
# print('Mean RMSE-----------')
# print()
# for index,i in enumerate(train_df.columns):
#     print('Feature: '+str(i))
#     rmse = []
#     for j in range(0,n_future):
#         rmse.append(math.sqrt(mean_squared_error(y_test[:,j-1,index],pred[:,j-1,index])))
#     print(mean(rmse))

# %% [raw]
# # Plot RMSE vs. steps:
#
# steps = list(range(n_future))
#
# for index,i in enumerate(train_df.columns):
#     print('Feature: '+str(i))
#     rmse = []
#     for j in range(0,n_future):
#         rmse.append(math.sqrt(mean_squared_error(y_test[:,j-1,index],pred[:,j-1,index])))
#
#     #Plots
#     plt.figure(figsize=(16,8))
#     plt.title('Root Mean Squared Error (RMSE) by Iteration Step - Feature: '+str(i))
#     plt.xlabel('Step [/]', fontsize=18)
#     plt.ylabel('RMSE [m]', fontsize=18)
#     plt.plot(steps, rmse)
#     plt.show()

# %%
# RMSE CORRECT Formula

print('RMSE for Features 0-5:')
print()
for i in range(0,6):
    rmse = np.sqrt(np.mean(((pred[0,:,i] - y_test[0,:,i]) ** 2))) #3rd var is index/feature no
    print(rmse)
# Out:
# RMSE for Features 0-5:
#
# 1642.0556999162272
# 3125.772222393553
# 4324.546338863684
# 0.09308088344212216
# 0.19338109035790108
# 0.3236547518663225

# %%
# RMSE CORRECT Formula

print('RMSE for Features 0-5:')
print()
for i in range(0,6):
    rmse = np.sqrt(mean_squared_error(y_test[0,:,i], pred[0,:,i]))
    print(rmse)
# Out:
# RMSE for Features 0-5:
#
# 1642.0556999162272
# 3125.772222393553
# 4324.546338863684
# 0.09308088344212216
# 0.19338109035790108
# 0.3236547518663225

# %% [raw]
# # Incorrect formula RMSE
# # RMSE
#
# print('RMSE for Features 0-5:')
# print()
# for i in range(0,6):
#     rmse = np.sqrt(((pred[0,:,i] - y_test[0,:,i]) ** 2)) #3rd var is index/feature no
#     print(np.mean(rmse))
#
#     # Plots
#     steps = list(range(n_future))
#     plt.figure(figsize=(16,8))
#     plt.title('Root Mean Squared Error (RMSE) by Iteration Step - Feature: '+str(i))
#     plt.xlabel('Step [/]', fontsize=18)
#     plt.ylabel('RMSE [m]', fontsize=18)
#     plt.plot(steps, rmse)
#     plt.show()

# %% [markdown]
# RMSE is not a step-by-step error, just the mean. So it's only 1 value per test per feature.

# %% [markdown]
# ## Errors:

# %% [markdown]
# ### 1. Absolute errors:

# %%
for i in range(0,6):
    print(i)
    dataa = {'testY': y_test[0,:,i], 'predictions': pred[0,:,i]}
    dff = pd.DataFrame.from_dict(dataa)
    
    dff['Error']=abs(dff.predictions-dff.testY)/max(dff.testY) # the normalization ct is taken as max of dataset
    plt.figure(figsize=(16,8))
    plt.title(f'Absolute Error plot for Feature {dictt[i]}:', fontsize=18)
    plt.xlabel('Step', fontsize=18)
    plt.ylabel('Absolute error [/]', fontsize=18)
    plt.plot(list(range(864,1000)), dff.Error)
    plt.show()
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
# AVG ABSOLUTE ERRORS:

print('Mean Absolute Errors:')
print()

for i in range(0,6):
    print('Feature '+str(dictt[i]))
    dataa = {'testY': y_test[0,:,i], 'predictions': pred[0,:,i]}
    dff = pd.DataFrame.from_dict(dataa)
    
    dff['Error']=abs(dff.predictions-dff.testY)/max(dff.testY) # the normalization ct is taken as max of dataset
    print(dff.Error.mean())
# Out:
# Mean Absolute Errors:
#
# Feature x
# 0.034603275974776075
# Feature y
# 0.06386888374731571
# Feature z
# 0.1498432799810484
# Feature x_velocity
# 0.027348493526907016
# Feature y_velocity
# 0.060684661578360825
# Feature z_velocity
# 0.15468271536401706

# %% [markdown]
# ### 2. Relative errors:

# %%
for i in range(0,6):
    print(i)
    dataa = {'testY': y_test[0,:,i], 'predictions': pred[0,:,i]}
    dff = pd.DataFrame.from_dict(dataa)
    
    dff['Error']=abs(dff.predictions-dff.testY)/dff.testY # the normalization ct is taken as ISS semi-major axis
    plt.figure(figsize=(16,8))
    plt.title(f'Relative Error plot for Feature {dictt[i]}:', fontsize=18)
    plt.xlabel('Step', fontsize=18)
    plt.ylabel('Relative error [%]', fontsize=18)
    plt.plot(list(range(864,1000)), dff.Error)
    plt.show()
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
# AVG RELATIVE ERRORS:

print('Mean Relative Errors:')
print()

for i in range(0,6):
    print('Feature '+str(dictt[i]))
    dataa = {'testY': y_test[0,:,i], 'predictions': pred[0,:,i]}
    dff = pd.DataFrame.from_dict(dataa)
    
    dff['Error']=abs(dff.predictions-dff.testY)/dff.testY * 100
    print(dff.Error.mean())
# Out:
# Mean Relative Errors:
#
# Feature x
# 5.822399229057328
# Feature y
# 5.056017866151075
# Feature z
# -25.121956724491522
# Feature x_velocity
# 1.7031780129028629
# Feature y_velocity
# -5.2902795738645585
# Feature z_velocity
# 170.43462131221887

# %% [markdown]
# ### 3. 3D Plots

# %% [markdown]
# Distance 3D:

# %%
df_pred=pd.DataFrame(columns=['x','y','z'])
test_df=pd.DataFrame(columns=['x','y','z'])

df_pred['x'] = pred[0,:,0]
df_pred['y'] = pred[0,:,1]
df_pred['z'] = pred[0,:,2]

test_df['x'] = y_test[0,:,0]
test_df['y'] = y_test[0,:,1]
test_df['z'] = y_test[0,:,2]

# %%
fig = plt.figure()
plt.figure(figsize=(50,20))

plt.axes(projection="3d")
x_line = df_pred['x']
y_line = df_pred['y']
z_line = df_pred['z']
plt.plot(x_line, y_line, z_line, 'red')

x_line2 = test_df['x']
y_line2 = test_df['y']
z_line2 = test_df['z']
plt.plot(x_line2, y_line2, z_line2, 'yellow')

plt.title('Predicted vs. Test Orbit 3D Propagation', fontsize=18)
plt.xlabel('x [km]', fontsize=18)
plt.ylabel('y [km]', fontsize=18)
#plt.zlabel('z [m]', fontsize=18)
plt.legend(['Predictions', 'Test'], loc='lower right', fontsize=18)
plt.show()

# %% [markdown]
# Velocities 3D:

# %%
df_pred=pd.DataFrame(columns=['x_vv','y_vv','z_vv'])
test_df=pd.DataFrame(columns=['x_vv','y_vv','z_vv'])

df_pred['x_vv'] = pred[0,:,3]
df_pred['y_vv'] = pred[0,:,4]
df_pred['z_vv'] = pred[0,:,5]

test_df['x_vv'] = y_test[0,:,3]
test_df['y_vv'] = y_test[0,:,4]
test_df['z_vv'] = y_test[0,:,5]

# %%
fig = plt.figure()
plt.figure(figsize=(50,20))

plt.axes(projection="3d")
x_line = df_pred['x_vv']
y_line = df_pred['y_vv']
z_line = df_pred['z_vv']
plt.plot(x_line, y_line, z_line, 'red')

x_line2 = test_df['x_vv']
y_line2 = test_df['y_vv']
z_line2 = test_df['z_vv']
plt.plot(x_line2, y_line2, z_line2, 'yellow')

plt.xlabel('x [km]', fontsize=18)
plt.ylabel('y [km]', fontsize=18)
plt.legend(['Predictions', 'Test'], loc='lower right')
plt.show()

# %% [markdown]
# ### 4. 3D Distance error:

# %%
# %%time
df_pred=pd.DataFrame(columns=['x','y','z'])
test_df=pd.DataFrame(columns=['x','y','z'])

df_pred['x'] = pred[0,:,0]
df_pred['y'] = pred[0,:,1]
df_pred['z'] = pred[0,:,2]

test_df['x'] = y_test[0,:,0]
test_df['y'] = y_test[0,:,1]
test_df['z'] = y_test[0,:,2]
# Out:
# Wall time: 5.98 ms

# %%
# Init empty DF for errors
df_err= pd.DataFrame(columns=['x_test', 'y_test', 'z_test', 'x_pred', 'y_pred', 'z_pred'])

df_err['x_test']=test_df['x']
df_err['y_test']=test_df['y']
df_err['z_test']=test_df['z']

df_err['x_pred']=df_pred['x']
df_err['y_pred']=df_pred['y']
df_err['z_pred']=df_pred['z']

# %%
# Difference in distance in 3D (Position)

df_err['distance_error'] = ( (df_err.x_test-df_err.x_pred)**2 + (df_err.y_test-df_err.y_pred)**2 + (df_err.z_test-df_err.z_pred)**2 )**(1/2)
df_err['distance_error'].apply(lambda x: float(x))

# 3D Distance difference plot vs time-stamp
plt.figure(figsize=(16,8))
plt.plot(list(range(864,1000)), df_err.distance_error)
plt.title('Distance error for 3D position vectors (r):')
plt.xlabel('Step', fontsize=18)
plt.ylabel('Distance Error [km]', fontsize=18)
plt.show()
