# %%
# Load DataFrame and Libs

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import seaborn as sns
#sns.set_style('whitegrid')
plt.style.use("fivethirtyeight")
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM

df = pd.read_csv('Dataframes/3rdBodyPerturbationPoliastro.csv')
df_v = pd.read_csv('Dataframes/3rdBodyPerturbationPoliastro_vv.csv')

df['x_vv']=df_v.vv_x
df['y_vv']=df_v.vv_y
df['z_vv']=df_v.vv_z

# %%
# Full 6D r,v elements

df
# Out:
#                 x             y             z      x_vv      y_vv      z_vv
# 0    42159.783600      0.000000      0.000000  0.000000  3.074505  0.053666
# 1    39159.545914  15563.916303    266.913399 -1.142984  2.852848  0.048528
# 2    30572.229294  28909.053086    496.928223 -2.127756  2.228986  0.039518
# 3    17596.068412  38144.740319    671.356184 -2.813645  1.287415  0.027234
# 4     2068.446366  41949.706443    775.646554 -3.098444  0.161675  0.012698
# ..            ...           ...           ...       ...       ...       ...
# 995  38132.961517  21370.880108  -7532.333000 -0.876644  2.199413  1.750026
# 996  31399.515894  31233.289707   1828.575655 -1.692745  1.562118  1.820311
# 997  20906.077447  37238.565267  10967.804062 -2.312211  0.726117  1.664753
# 998   7871.245318  38575.122415  18731.818721 -2.661184 -0.221639  1.293445
# 999  -6142.526530  34919.272230  24066.202237 -2.681132 -1.179765  0.734721
#
# [1000 rows x 6 columns]

# %%
# convert an array of values into a dataset matrix

def create_dataset(dataset, look_back):
    dataX = []
    dataY = []
    for i in range(len(dataset) - look_back):
        a = dataset[i:(i + look_back), :]
        dataX.append(a)
        dataY.append(dataset[i + look_back, predicted_feature]) # 2 stands for prediction of Z!!! (3rd col)
    return np.array(dataX), np.array(dataY)

# %%
# Function

def train_vector(df, predicted_feature):
    
    # load the dataset
    dataset = df.values
    
    # split into train and test sets
    train_size = int(len(dataset) * 0.8) 
    test_size = len(dataset) - train_size
    train=dataset[0 : train_size]
    test=dataset[train_size - 60 : ]
    
    #Scale the data
    scaler = MinMaxScaler()
    train = scaler.fit_transform(train)
    test = scaler.transform(test)
    # reshape into X=t and Y=t+1
    look_back = 60 # this is the window
    trainX, trainY = create_dataset(train, look_back)  
    testX, testY = create_dataset(test, look_back)
    # reshape input to be  [length of train/test data, window size (def=60), features]
    trainX = np.reshape(trainX, (trainX.shape[0], look_back, 6))
    testX = np.reshape(testX, (testX.shape[0],look_back, 6))
    
    # Build the LSTM model
    # Note: replace LSTM with GRU or RNN if you want to try those
    model = Sequential()
    model.add(LSTM(128, return_sequences=True, input_shape= (look_back, 6)))
    model.add(LSTM(64, return_sequences=False))
    model.add(Dense(25))
    model.add(Dense(1))
    # Compile the model
    model.compile(optimizer='adam', loss='mean_squared_error')
    # Train the model
    history=model.fit(trainX, trainY, batch_size=256, epochs=100)

    predictions = model.predict(testX)
    predict_ext = np.zeros((len(predictions), 6))
    predict_ext[:,predicted_feature] = predictions[:,0]
    predictions = scaler.inverse_transform(predict_ext)[:,predicted_feature]
    
    testY_extended = np.zeros((len(testY),6))
    testY_extended[:,predicted_feature]=testY
    testY=scaler.inverse_transform(testY_extended)[:,predicted_feature]
    
    rmse = np.sqrt(np.mean(((predictions - testY) ** 2)))
    print(f'RMSE for feature {predicted_feature} is: ' + str(rmse))
    
    pred=np.reshape(predictions, (predictions.shape[0]))
    pred_s=pd.Series(pred)
    df_pred[str(predicted_feature)]=pred_s
    
    #Output dataframe of predictions in 6 dimensions r,v
    return df_pred

# %% [raw]
# # Call
#
# train_vector(df, 0)

# %%
# Call for full 6D training

# Init empty predictions DF
df_pred= pd.DataFrame(columns=['0', '1', '2', '3', '4', '5'])

for predicted_feature in range(0,6):
    train_vector(df, predicted_feature)

#Rename predictions df columns from numerals
df_pred.columns=['x', 'y', 'z', 'x_vv', 'y_vv', 'z_vv']
df_pred
# Out:
# Epoch 1/100
# 3/3 [==============================] - 0s 145ms/step - loss: 0.1969
# Epoch 2/100
# 3/3 [==============================] - 0s 143ms/step - loss: 0.1202
# Epoch 3/100
# 3/3 [==============================] - 0s 144ms/step - loss: 0.0920
# Epoch 4/100
# 3/3 [==============================] - 0s 126ms/step - loss: 0.0666
# Epoch 5/100
# 3/3 [==============================] - 0s 124ms/step - loss: 0.0400
# Epoch 6/100
# 3/3 [==============================] - 0s 131ms/step - loss: 0.0250
# Epoch 7/100
# 3/3 [==============================] - 0s 131ms/step - loss: 0.0059
# Epoch 8/100
# 3/3 [==============================] - 0s 141ms/step - loss: 0.0070
# Epoch 9/100
# 3/3 [==============================] - 0s 133ms/step - loss: 0.0082
# Epoch 10/100
# 3/3 [==============================] - 0s 136ms/step - loss: 0.0081
# Epoch 11/100
# 3/3 [==============================] - 0s 124ms/step - loss: 0.0030
# Epoch 12/100
# 3/3 [==============================] - 0s 133ms/step - loss: 0.0026
# Epoch 13/100
# 3/3 [==============================] - 0s 117ms/step - loss: 0.0019
# Epoch 14/100
# 3/3 [==============================] - 0s 129ms/step - loss: 0.0028
# Epoch 15/100
# 3/3 [==============================] - 0s 130ms/step - loss: 0.0023
# Epoch 16/100
# 3/3 [==============================] - 0s 128ms/step - loss: 0.0018
# Epoch 17/100
# 3/3 [==============================] - 0s 130ms/step - loss: 0.0013
# Epoch 18/100
# 3/3 [==============================] - 0s 126ms/step - loss: 0.0011
# Epoch 19/100
# 3/3 [==============================] - 0s 127ms/step - loss: 0.0012
# Epoch 20/100
# 3/3 [==============================] - 0s 121ms/step - loss: 0.0011
# Epoch 21/100
# 3/3 [==============================] - 0s 124ms/step - loss: 0.0010
# Epoch 22/100
# 3/3 [==============================] - 0s 131ms/step - loss: 8.4575e-04
# Epoch 23/100
# 3/3 [==============================] - 0s 124ms/step - loss: 8.3603e-04
# Epoch 24/100
# 3/3 [==============================] - 0s 124ms/step - loss: 8.0463e-04
# Epoch 25/100
# 3/3 [==============================] - 0s 138ms/step - loss: 8.0597e-04
# Epoch 26/100
# 3/3 [==============================] - 0s 123ms/step - loss: 7.4012e-04
# Epoch 27/100
# 3/3 [==============================] - 0s 134ms/step - loss: 6.9049e-04
# Epoch 28/100
# 3/3 [==============================] - 0s 122ms/step - loss: 6.6284e-04
# Epoch 29/100
# 3/3 [==============================] - 0s 136ms/step - loss: 6.6144e-04
# Epoch 30/100
# 3/3 [==============================] - 0s 132ms/step - loss: 6.3486e-04
# Epoch 31/100
# 3/3 [==============================] - 0s 140ms/step - loss: 6.0661e-04
# Epoch 32/100
# 3/3 [==============================] - 0s 129ms/step - loss: 5.7935e-04
# Epoch 33/100
# 3/3 [==============================] - 0s 127ms/step - loss: 5.6492e-04
# Epoch 34/100
# 3/3 [==============================] - 0s 128ms/step - loss: 5.4821e-04 0s - loss: 5.4821e-0
# Epoch 35/100
# 3/3 [==============================] - 0s 132ms/step - loss: 5.2967e-04
# Epoch 36/100
# 3/3 [==============================] - 0s 137ms/step - loss: 5.1145e-04
# Epoch 37/100
# 3/3 [==============================] - 0s 134ms/step - loss: 4.9749e-04
# Epoch 38/100
# 3/3 [==============================] - 0s 126ms/step - loss: 4.8561e-04
# Epoch 39/100
# 3/3 [==============================] - 0s 126ms/step - loss: 4.7024e-04
# Epoch 40/100
# 3/3 [==============================] - 0s 129ms/step - loss: 4.5816e-04
# Epoch 41/100
# 3/3 [==============================] - 0s 133ms/step - loss: 4.4647e-04
# Epoch 42/100
# 3/3 [==============================] - 0s 125ms/step - loss: 4.3357e-04
# Epoch 43/100
# 3/3 [==============================] - 0s 126ms/step - loss: 4.2290e-04
# Epoch 44/100
# 3/3 [==============================] - 0s 127ms/step - loss: 4.1013e-04
# Epoch 45/100
# 3/3 [==============================] - 0s 136ms/step - loss: 4.0215e-04
# Epoch 46/100
# 3/3 [==============================] - 0s 133ms/step - loss: 3.9063e-04
# Epoch 47/100
# 3/3 [==============================] - 0s 126ms/step - loss: 3.8158e-04
# Epoch 48/100
# 3/3 [==============================] - 0s 134ms/step - loss: 3.7113e-04
# Epoch 49/100
# 3/3 [==============================] - 0s 127ms/step - loss: 3.6154e-04
# Epoch 50/100
# 3/3 [==============================] - 0s 133ms/step - loss: 3.5336e-04 0s - loss: 3.5336e-0
# Epoch 51/100
# 3/3 [==============================] - 0s 123ms/step - loss: 3.4317e-04
# Epoch 52/100
# 3/3 [==============================] - 0s 127ms/step - loss: 3.3462e-04
# Epoch 53/100
# 3/3 [==============================] - 0s 131ms/step - loss: 3.2625e-04
# Epoch 54/100
# 3/3 [==============================] - 0s 131ms/step - loss: 3.1855e-04
# Epoch 55/100
# 3/3 [==============================] - 0s 124ms/step - loss: 3.0905e-04
# Epoch 56/100
# 3/3 [==============================] - 0s 136ms/step - loss: 3.0223e-04
# Epoch 57/100
# 3/3 [==============================] - 0s 135ms/step - loss: 2.9309e-04
# Epoch 58/100
# 3/3 [==============================] - 0s 114ms/step - loss: 2.8555e-04
# Epoch 59/100
# 3/3 [==============================] - 0s 118ms/step - loss: 2.7656e-04
# Epoch 60/100
# 3/3 [==============================] - 0s 132ms/step - loss: 2.6914e-04
# Epoch 61/100
# 3/3 [==============================] - 0s 129ms/step - loss: 2.6060e-04
# Epoch 62/100
# 3/3 [==============================] - 0s 139ms/step - loss: 2.5307e-04
# Epoch 63/100
# 3/3 [==============================] - 0s 132ms/step - loss: 2.4545e-04
# Epoch 64/100
# 3/3 [==============================] - 0s 139ms/step - loss: 2.3712e-04
# Epoch 65/100
# 3/3 [==============================] - 0s 135ms/step - loss: 2.2991e-04
# Epoch 66/100
# 3/3 [==============================] - 0s 118ms/step - loss: 2.2470e-04
# Epoch 67/100
# 3/3 [==============================] - 0s 121ms/step - loss: 2.1536e-04 0s - loss: 2.0994e-
# Epoch 68/100
# 3/3 [==============================] - 0s 128ms/step - loss: 2.0719e-04
# Epoch 69/100
# 3/3 [==============================] - 1s 441ms/step - loss: 2.0098e-04
# Epoch 70/100
# 3/3 [==============================] - 1s 452ms/step - loss: 1.9171e-04
# Epoch 71/100
# 3/3 [==============================] - 1s 469ms/step - loss: 1.8527e-04
# Epoch 72/100
# 3/3 [==============================] - 1s 234ms/step - loss: 1.7697e-04
# Epoch 73/100
# 3/3 [==============================] - 1s 198ms/step - loss: 1.6896e-04
# Epoch 74/100
# 3/3 [==============================] - 1s 214ms/step - loss: 1.6318e-04
# Epoch 75/100
# 3/3 [==============================] - 1s 188ms/step - loss: 1.5781e-04
# Epoch 76/100
# 3/3 [==============================] - 1s 201ms/step - loss: 1.5146e-04
# Epoch 77/100
# 3/3 [==============================] - 1s 175ms/step - loss: 1.4678e-04
# Epoch 78/100
# 3/3 [==============================] - 0s 165ms/step - loss: 1.3896e-04
# Epoch 79/100
# 3/3 [==============================] - 1s 170ms/step - loss: 1.3241e-04
# Epoch 80/100
# 3/3 [==============================] - 1s 178ms/step - loss: 1.2813e-04
# Epoch 81/100
# 3/3 [==============================] - 1s 359ms/step - loss: 1.1942e-04
# Epoch 82/100
# 3/3 [==============================] - 1s 313ms/step - loss: 1.1370e-04
# Epoch 83/100
# 3/3 [==============================] - 1s 267ms/step - loss: 1.0896e-04
# Epoch 84/100
# 3/3 [==============================] - 1s 243ms/step - loss: 1.0513e-04
# Epoch 85/100
# 3/3 [==============================] - 1s 229ms/step - loss: 1.0119e-04
# Epoch 86/100
# 3/3 [==============================] - 1s 191ms/step - loss: 9.8511e-05
# Epoch 87/100
# 3/3 [==============================] - 0s 146ms/step - loss: 9.3947e-05
# Epoch 88/100
# 3/3 [==============================] - 0s 148ms/step - loss: 9.2069e-05
# Epoch 89/100
# 3/3 [==============================] - 0s 158ms/step - loss: 8.9982e-05
# Epoch 90/100
# 3/3 [==============================] - 0s 145ms/step - loss: 8.9736e-05
# Epoch 91/100
# 3/3 [==============================] - 0s 143ms/step - loss: 8.5494e-05
# Epoch 92/100
# 3/3 [==============================] - 1s 171ms/step - loss: 8.4697e-05
# Epoch 93/100
# 3/3 [==============================] - 0s 154ms/step - loss: 8.3223e-05
# Epoch 94/100
# 3/3 [==============================] - 0s 144ms/step - loss: 8.0920e-05
# Epoch 95/100
# 3/3 [==============================] - 0s 141ms/step - loss: 7.9279e-05
# Epoch 96/100
# 3/3 [==============================] - 0s 136ms/step - loss: 8.2395e-05
# Epoch 97/100
# 3/3 [==============================] - 0s 141ms/step - loss: 7.6685e-05
# Epoch 98/100
# 3/3 [==============================] - 0s 162ms/step - loss: 7.8823e-05
# Epoch 99/100
# 3/3 [==============================] - 1s 196ms/step - loss: 7.5896e-05
# Epoch 100/100
# 3/3 [==============================] - 1s 192ms/step - loss: 7.1385e-05
# RMSE for feature 0 is: 885.8479111884631
# Epoch 1/100
# 3/3 [==============================] - 0s 139ms/step - loss: 0.1447
# Epoch 2/100
# 3/3 [==============================] - 1s 176ms/step - loss: 0.0713
# Epoch 3/100
# 3/3 [==============================] - 1s 185ms/step - loss: 0.0455
# Epoch 4/100
# 3/3 [==============================] - 1s 170ms/step - loss: 0.0158
# Epoch 5/100
# 3/3 [==============================] - 1s 189ms/step - loss: 0.0121
# Epoch 6/100
# 3/3 [==============================] - 1s 184ms/step - loss: 0.0039
# Epoch 7/100
# 3/3 [==============================] - 1s 181ms/step - loss: 0.0102
# Epoch 8/100
# 3/3 [==============================] - 1s 177ms/step - loss: 0.0056
# Epoch 9/100
# 3/3 [==============================] - 1s 180ms/step - loss: 0.0049
# Epoch 10/100
# 3/3 [==============================] - 1s 172ms/step - loss: 0.0016
# Epoch 11/100
# 3/3 [==============================] - 1s 178ms/step - loss: 0.0027
# Epoch 12/100
# 3/3 [==============================] - 1s 312ms/step - loss: 0.0023
# Epoch 13/100
# 3/3 [==============================] - 1s 375ms/step - loss: 0.0023
# Epoch 14/100
# 3/3 [==============================] - 1s 298ms/step - loss: 0.0020
# Epoch 15/100
# 3/3 [==============================] - 1s 272ms/step - loss: 0.0012
# Epoch 16/100
# 3/3 [==============================] - 1s 239ms/step - loss: 0.0013
# Epoch 17/100
# 3/3 [==============================] - 1s 236ms/step - loss: 0.0011
# Epoch 18/100
# 3/3 [==============================] - 0s 146ms/step - loss: 0.0013
# Epoch 19/100
# 3/3 [==============================] - 0s 141ms/step - loss: 0.0011
# Epoch 20/100
# 3/3 [==============================] - 0s 144ms/step - loss: 0.0010
# Epoch 21/100
# 3/3 [==============================] - 0s 136ms/step - loss: 9.2579e-04
# Epoch 22/100
# 3/3 [==============================] - 0s 152ms/step - loss: 9.2719e-04
# Epoch 23/100
# 3/3 [==============================] - 0s 150ms/step - loss: 8.8826e-04
# Epoch 24/100
# 3/3 [==============================] - 0s 149ms/step - loss: 8.6259e-04
# Epoch 25/100
# 3/3 [==============================] - 0s 163ms/step - loss: 8.0250e-04
# Epoch 26/100
# 3/3 [==============================] - 0s 144ms/step - loss: 7.9564e-04
# Epoch 27/100
# 3/3 [==============================] - 0s 144ms/step - loss: 7.6827e-04
# Epoch 28/100
# 3/3 [==============================] - 0s 138ms/step - loss: 7.5680e-04
# Epoch 29/100
# 3/3 [==============================] - 0s 152ms/step - loss: 7.3245e-04
# Epoch 30/100
# 3/3 [==============================] - 1s 170ms/step - loss: 7.0719e-04
# Epoch 31/100
# 3/3 [==============================] - 1s 197ms/step - loss: 6.8318e-04
# Epoch 32/100
# 3/3 [==============================] - 1s 168ms/step - loss: 6.6904e-04
# Epoch 33/100
# 3/3 [==============================] - 0s 159ms/step - loss: 6.4715e-04
# Epoch 34/100
# 3/3 [==============================] - 0s 164ms/step - loss: 6.2831e-04
# Epoch 35/100
# 3/3 [==============================] - 0s 164ms/step - loss: 6.1162e-04
# Epoch 36/100
# 3/3 [==============================] - 0s 159ms/step - loss: 5.9836e-04
# Epoch 37/100
# 3/3 [==============================] - 1s 173ms/step - loss: 5.8350e-04
# Epoch 38/100
# 3/3 [==============================] - 0s 165ms/step - loss: 5.6700e-04
# Epoch 39/100
# 3/3 [==============================] - 0s 136ms/step - loss: 5.5312e-04 0s - loss: 5.4758e-
# Epoch 40/100
# 3/3 [==============================] - 0s 130ms/step - loss: 5.3918e-04
# Epoch 41/100
# 3/3 [==============================] - 0s 128ms/step - loss: 5.2260e-04
# Epoch 42/100
# 3/3 [==============================] - 0s 129ms/step - loss: 5.1200e-04
# Epoch 43/100
# 3/3 [==============================] - 0s 128ms/step - loss: 4.9821e-04
# Epoch 44/100
# 3/3 [==============================] - 0s 127ms/step - loss: 4.8606e-04
# Epoch 45/100
# 3/3 [==============================] - 0s 121ms/step - loss: 4.7295e-04
# Epoch 46/100
# 3/3 [==============================] - 0s 129ms/step - loss: 4.6102e-04
# Epoch 47/100
# 3/3 [==============================] - 0s 132ms/step - loss: 4.4946e-04
# Epoch 48/100
# 3/3 [==============================] - 0s 133ms/step - loss: 4.3821e-04
# Epoch 49/100
# 3/3 [==============================] - 0s 129ms/step - loss: 4.2649e-04
# Epoch 50/100
# 3/3 [==============================] - 0s 121ms/step - loss: 4.1612e-04
# Epoch 51/100
# 3/3 [==============================] - 0s 126ms/step - loss: 4.0440e-04
# Epoch 52/100
# 3/3 [==============================] - 0s 125ms/step - loss: 3.9416e-04
# Epoch 53/100
# 3/3 [==============================] - 0s 128ms/step - loss: 3.8201e-04
# Epoch 54/100
# 3/3 [==============================] - 0s 159ms/step - loss: 3.7303e-04
# Epoch 55/100
# 3/3 [==============================] - 0s 145ms/step - loss: 3.6112e-04
# Epoch 56/100
# 3/3 [==============================] - 0s 145ms/step - loss: 3.5315e-04
# Epoch 57/100
# 3/3 [==============================] - 0s 140ms/step - loss: 3.3870e-04
# Epoch 58/100
# 3/3 [==============================] - 0s 159ms/step - loss: 3.2925e-04
# Epoch 59/100
# 3/3 [==============================] - 0s 142ms/step - loss: 3.1942e-04
# Epoch 60/100
# 3/3 [==============================] - 0s 134ms/step - loss: 3.0553e-04
# Epoch 61/100
# 3/3 [==============================] - 0s 145ms/step - loss: 2.9940e-04
# Epoch 62/100
# 3/3 [==============================] - 0s 144ms/step - loss: 2.8684e-04
# Epoch 63/100
# 3/3 [==============================] - 0s 142ms/step - loss: 2.7384e-04
# Epoch 64/100
# 3/3 [==============================] - 0s 134ms/step - loss: 2.6597e-04
# Epoch 65/100
# 3/3 [==============================] - 0s 139ms/step - loss: 2.5346e-04
# Epoch 66/100
# 3/3 [==============================] - 0s 116ms/step - loss: 2.4213e-04
# Epoch 67/100
# 3/3 [==============================] - 0s 131ms/step - loss: 2.3286e-04
# Epoch 68/100
# 3/3 [==============================] - 0s 128ms/step - loss: 2.2146e-04
# Epoch 69/100
# 3/3 [==============================] - 0s 121ms/step - loss: 2.1248e-04
# Epoch 70/100
# 3/3 [==============================] - 0s 123ms/step - loss: 2.0093e-04
# Epoch 71/100
# 3/3 [==============================] - 0s 120ms/step - loss: 1.9123e-04
# Epoch 72/100
# 3/3 [==============================] - 0s 135ms/step - loss: 1.8032e-04
# Epoch 73/100
# 3/3 [==============================] - 0s 140ms/step - loss: 1.6996e-04
# Epoch 74/100
# 3/3 [==============================] - 0s 129ms/step - loss: 1.5834e-04
# Epoch 75/100
# 3/3 [==============================] - 0s 123ms/step - loss: 1.4883e-04
# Epoch 76/100
# 3/3 [==============================] - 0s 114ms/step - loss: 1.3844e-04
# Epoch 77/100
# 3/3 [==============================] - 0s 122ms/step - loss: 1.2942e-04
# Epoch 78/100
# 3/3 [==============================] - 0s 127ms/step - loss: 1.2014e-04
# Epoch 79/100
# 3/3 [==============================] - 0s 128ms/step - loss: 1.1148e-04
# Epoch 80/100
# 3/3 [==============================] - 0s 164ms/step - loss: 1.0380e-04
# Epoch 81/100
# 3/3 [==============================] - 0s 159ms/step - loss: 9.5990e-05
# Epoch 82/100
# 3/3 [==============================] - 0s 143ms/step - loss: 8.9915e-05
# Epoch 83/100
# 3/3 [==============================] - 0s 143ms/step - loss: 8.7849e-05
# Epoch 84/100
# 3/3 [==============================] - 0s 146ms/step - loss: 7.9715e-05
# Epoch 85/100
# 3/3 [==============================] - 0s 138ms/step - loss: 7.2917e-05
# Epoch 86/100
# 3/3 [==============================] - 0s 139ms/step - loss: 6.8418e-05
# Epoch 87/100
# 3/3 [==============================] - 0s 146ms/step - loss: 6.2453e-05
# Epoch 88/100
# 3/3 [==============================] - 0s 137ms/step - loss: 6.0895e-05
# Epoch 89/100
# 3/3 [==============================] - 0s 140ms/step - loss: 5.7803e-05
# Epoch 90/100
# 3/3 [==============================] - 0s 118ms/step - loss: 5.4163e-05
# Epoch 91/100
# 3/3 [==============================] - 0s 122ms/step - loss: 5.2521e-05
# Epoch 92/100
# 3/3 [==============================] - 0s 127ms/step - loss: 5.3700e-05
# Epoch 93/100
# 3/3 [==============================] - 0s 119ms/step - loss: 5.4367e-05
# Epoch 94/100
# 3/3 [==============================] - 0s 129ms/step - loss: 5.2311e-05
# Epoch 95/100
# 3/3 [==============================] - 0s 120ms/step - loss: 5.2917e-05
# Epoch 96/100
# 3/3 [==============================] - 0s 132ms/step - loss: 5.0568e-05
# Epoch 97/100
# 3/3 [==============================] - 0s 138ms/step - loss: 5.2436e-05
# Epoch 98/100
# 3/3 [==============================] - 0s 126ms/step - loss: 5.1158e-05
# Epoch 99/100
# 3/3 [==============================] - 0s 134ms/step - loss: 5.1917e-05
# Epoch 100/100
# 3/3 [==============================] - 0s 124ms/step - loss: 4.9997e-05
# RMSE for feature 1 is: 852.1000782715399
# Epoch 1/100
# 3/3 [==============================] - 1s 240ms/step - loss: 0.0965
# Epoch 2/100
# 3/3 [==============================] - 1s 213ms/step - loss: 0.0436
# Epoch 3/100
# 3/3 [==============================] - 1s 215ms/step - loss: 0.0419
# Epoch 4/100
# 3/3 [==============================] - 1s 194ms/step - loss: 0.0236
# Epoch 5/100
# 3/3 [==============================] - 1s 192ms/step - loss: 0.0195
# Epoch 6/100
# 3/3 [==============================] - 1s 203ms/step - loss: 0.0162
# Epoch 7/100
# 3/3 [==============================] - 1s 498ms/step - loss: 0.0104
# Epoch 8/100
# 3/3 [==============================] - 1s 376ms/step - loss: 0.0127
# Epoch 9/100
# 3/3 [==============================] - 1s 337ms/step - loss: 0.0096
# Epoch 10/100
# 3/3 [==============================] - 1s 292ms/step - loss: 0.0104
# Epoch 11/100
# 3/3 [==============================] - 1s 272ms/step - loss: 0.0096
# Epoch 12/100
# 3/3 [==============================] - 1s 168ms/step - loss: 0.0086
# Epoch 13/100
# 3/3 [==============================] - 0s 159ms/step - loss: 0.0088
# Epoch 14/100
# 3/3 [==============================] - 0s 163ms/step - loss: 0.0077
# Epoch 15/100
# 3/3 [==============================] - 1s 175ms/step - loss: 0.0077
# Epoch 16/100
# 3/3 [==============================] - 0s 165ms/step - loss: 0.0074
# Epoch 17/100
# 3/3 [==============================] - 0s 162ms/step - loss: 0.0070
# Epoch 18/100
# 3/3 [==============================] - 0s 163ms/step - loss: 0.0068
# Epoch 19/100
# 3/3 [==============================] - 0s 161ms/step - loss: 0.0063
# Epoch 20/100
# 3/3 [==============================] - 0s 161ms/step - loss: 0.0061
# Epoch 21/100
# 3/3 [==============================] - 1s 209ms/step - loss: 0.0056
# Epoch 22/100
# 3/3 [==============================] - 1s 221ms/step - loss: 0.0054
# Epoch 23/100
# 3/3 [==============================] - 1s 210ms/step - loss: 0.0050
# Epoch 24/100
# 3/3 [==============================] - 1s 202ms/step - loss: 0.0046
# Epoch 25/100
# 3/3 [==============================] - 1s 190ms/step - loss: 0.0043
# Epoch 26/100
# 3/3 [==============================] - 1s 195ms/step - loss: 0.0038
# Epoch 27/100
# 3/3 [==============================] - 1s 184ms/step - loss: 0.0034
# Epoch 28/100
# 3/3 [==============================] - 1s 171ms/step - loss: 0.0030
# Epoch 29/100
# 3/3 [==============================] - 0s 150ms/step - loss: 0.0026
# Epoch 30/100
# 3/3 [==============================] - 0s 146ms/step - loss: 0.0021
# Epoch 31/100
# 3/3 [==============================] - 0s 161ms/step - loss: 0.0017
# Epoch 32/100
# 3/3 [==============================] - 0s 144ms/step - loss: 0.0012
# Epoch 33/100
# 3/3 [==============================] - 0s 148ms/step - loss: 8.6584e-04
# Epoch 34/100
# 3/3 [==============================] - 0s 152ms/step - loss: 5.7808e-04
# Epoch 35/100
# 3/3 [==============================] - 0s 148ms/step - loss: 3.5654e-04
# Epoch 36/100
# 3/3 [==============================] - 0s 156ms/step - loss: 2.5468e-04
# Epoch 37/100
# 3/3 [==============================] - 0s 144ms/step - loss: 2.4919e-04
# Epoch 38/100
# 3/3 [==============================] - 0s 143ms/step - loss: 2.7502e-04
# Epoch 39/100
# 3/3 [==============================] - 0s 149ms/step - loss: 2.7447e-04
# Epoch 40/100
# 3/3 [==============================] - 0s 141ms/step - loss: 2.4345e-04
# Epoch 41/100
# 3/3 [==============================] - 0s 152ms/step - loss: 2.0021e-04
# Epoch 42/100
# 3/3 [==============================] - 1s 183ms/step - loss: 1.6448e-04
# Epoch 43/100
# 3/3 [==============================] - 0s 166ms/step - loss: 1.4389e-04
# Epoch 44/100
# 3/3 [==============================] - 0s 159ms/step - loss: 1.3210e-04
# Epoch 45/100
# 3/3 [==============================] - 0s 164ms/step - loss: 1.3008e-04
# Epoch 46/100
# 3/3 [==============================] - 0s 155ms/step - loss: 1.3002e-04
# Epoch 47/100
# 3/3 [==============================] - 0s 161ms/step - loss: 1.2528e-04
# Epoch 48/100
# 3/3 [==============================] - 1s 172ms/step - loss: 1.1054e-04
# Epoch 49/100
# 3/3 [==============================] - 0s 162ms/step - loss: 1.0462e-04
# Epoch 50/100
# 3/3 [==============================] - 0s 154ms/step - loss: 9.4939e-05
# Epoch 51/100
# 3/3 [==============================] - 0s 134ms/step - loss: 9.0149e-05
# Epoch 52/100
# 3/3 [==============================] - 0s 147ms/step - loss: 9.0508e-05
# Epoch 53/100
# 3/3 [==============================] - 0s 143ms/step - loss: 8.7517e-05
# Epoch 54/100
# 3/3 [==============================] - 0s 139ms/step - loss: 7.6854e-05
# Epoch 55/100
# 3/3 [==============================] - 0s 147ms/step - loss: 7.1020e-05
# Epoch 56/100
# 3/3 [==============================] - 0s 146ms/step - loss: 6.7060e-05
# Epoch 57/100
# 3/3 [==============================] - 0s 146ms/step - loss: 6.2490e-05
# Epoch 58/100
# 3/3 [==============================] - 0s 155ms/step - loss: 6.0085e-05
# Epoch 59/100
# 3/3 [==============================] - 0s 148ms/step - loss: 5.5066e-05
# Epoch 60/100
# 3/3 [==============================] - 0s 158ms/step - loss: 5.2217e-05
# Epoch 61/100
# 3/3 [==============================] - 0s 155ms/step - loss: 5.1964e-05
# Epoch 62/100
# 3/3 [==============================] - 0s 149ms/step - loss: 5.0154e-05
# Epoch 63/100
# 3/3 [==============================] - 0s 134ms/step - loss: 4.7807e-05
# Epoch 64/100
# 3/3 [==============================] - 0s 147ms/step - loss: 4.7217e-05
# Epoch 65/100
# 3/3 [==============================] - 1s 167ms/step - loss: 6.6317e-05
# Epoch 66/100
# 3/3 [==============================] - 0s 166ms/step - loss: 7.3449e-05
# Epoch 67/100
# 3/3 [==============================] - 0s 162ms/step - loss: 6.3185e-05
# Epoch 68/100
# 3/3 [==============================] - 0s 156ms/step - loss: 5.4166e-05
# Epoch 69/100
# 3/3 [==============================] - 0s 156ms/step - loss: 5.4622e-05
# Epoch 70/100
# 3/3 [==============================] - 0s 149ms/step - loss: 4.4570e-05
# Epoch 71/100
# 3/3 [==============================] - 0s 156ms/step - loss: 4.9686e-05
# Epoch 72/100
# 3/3 [==============================] - 0s 153ms/step - loss: 4.4587e-05
# Epoch 73/100
# 3/3 [==============================] - 0s 149ms/step - loss: 4.6143e-05
# Epoch 74/100
# 3/3 [==============================] - 0s 134ms/step - loss: 4.5530e-05
# Epoch 75/100
# 3/3 [==============================] - 0s 131ms/step - loss: 3.6040e-05
# Epoch 76/100
# 3/3 [==============================] - 0s 135ms/step - loss: 4.1999e-05
# Epoch 77/100
# 3/3 [==============================] - 0s 137ms/step - loss: 3.7876e-05
# Epoch 78/100
# 3/3 [==============================] - 0s 140ms/step - loss: 3.9860e-05
# Epoch 79/100
# 3/3 [==============================] - 0s 137ms/step - loss: 4.5867e-05
# Epoch 80/100
# 3/3 [==============================] - 0s 128ms/step - loss: 5.3796e-05
# Epoch 81/100
# 3/3 [==============================] - 0s 135ms/step - loss: 5.8476e-05
# Epoch 82/100
# 3/3 [==============================] - 0s 144ms/step - loss: 4.8097e-05
# Epoch 83/100
# 3/3 [==============================] - 0s 143ms/step - loss: 6.9889e-05
# Epoch 84/100
# 3/3 [==============================] - 0s 145ms/step - loss: 4.9064e-05
# Epoch 85/100
# 3/3 [==============================] - 0s 138ms/step - loss: 5.0183e-05
# Epoch 86/100
# 3/3 [==============================] - 0s 144ms/step - loss: 9.6667e-05
# Epoch 87/100
# 3/3 [==============================] - 0s 146ms/step - loss: 5.4942e-05
# Epoch 88/100
# 3/3 [==============================] - 0s 153ms/step - loss: 4.8900e-05
# Epoch 89/100
# 3/3 [==============================] - 1s 178ms/step - loss: 5.2869e-05
# Epoch 90/100
# 3/3 [==============================] - 1s 168ms/step - loss: 4.5163e-05
# Epoch 91/100
# 3/3 [==============================] - 0s 162ms/step - loss: 4.0016e-05
# Epoch 92/100
# 3/3 [==============================] - 0s 156ms/step - loss: 3.7769e-05
# Epoch 93/100
# 3/3 [==============================] - 0s 152ms/step - loss: 3.8902e-05
# Epoch 94/100
# 3/3 [==============================] - 0s 143ms/step - loss: 3.9161e-05
# Epoch 95/100
# 3/3 [==============================] - 0s 150ms/step - loss: 4.4737e-05
# Epoch 96/100
# 3/3 [==============================] - 0s 151ms/step - loss: 3.9727e-05
# Epoch 97/100
# 3/3 [==============================] - 0s 148ms/step - loss: 3.9063e-05
# Epoch 98/100
# 3/3 [==============================] - 0s 133ms/step - loss: 3.8109e-05
# Epoch 99/100
# 3/3 [==============================] - 0s 136ms/step - loss: 3.9294e-05
# Epoch 100/100
# 3/3 [==============================] - 0s 138ms/step - loss: 3.7534e-05
# RMSE for feature 2 is: 487.31661239533156
# Epoch 1/100
# 3/3 [==============================] - 2s 651ms/step - loss: 0.2318
# Epoch 2/100
# 3/3 [==============================] - 2s 549ms/step - loss: 0.1443
# Epoch 3/100
# 3/3 [==============================] - 2s 519ms/step - loss: 0.0876
# Epoch 4/100
# 3/3 [==============================] - 1s 491ms/step - loss: 0.0853
# Epoch 5/100
# 3/3 [==============================] - 1s 178ms/step - loss: 0.0508
# Epoch 6/100
# 3/3 [==============================] - 1s 194ms/step - loss: 0.0417
# Epoch 7/100
# 3/3 [==============================] - 1s 175ms/step - loss: 0.0207
# Epoch 8/100
# 3/3 [==============================] - 1s 172ms/step - loss: 0.0120
# Epoch 9/100
# 3/3 [==============================] - 1s 180ms/step - loss: 0.0041
# Epoch 10/100
# 3/3 [==============================] - 1s 171ms/step - loss: 0.0082
# Epoch 11/100
# 3/3 [==============================] - 1s 185ms/step - loss: 0.0078
# Epoch 12/100
# 3/3 [==============================] - 1s 293ms/step - loss: 0.0067
# Epoch 13/100
# 3/3 [==============================] - 1s 270ms/step - loss: 0.0036
# Epoch 14/100
# 3/3 [==============================] - 1s 270ms/step - loss: 0.0026
# Epoch 15/100
# 3/3 [==============================] - 1s 235ms/step - loss: 0.0031
# Epoch 16/100
# 3/3 [==============================] - 1s 240ms/step - loss: 0.0032
# Epoch 17/100
# 3/3 [==============================] - 1s 229ms/step - loss: 0.0029
# Epoch 18/100
# 3/3 [==============================] - 0s 163ms/step - loss: 0.0024
# Epoch 19/100
# 3/3 [==============================] - 0s 165ms/step - loss: 0.0019
# Epoch 20/100
# 3/3 [==============================] - 0s 160ms/step - loss: 0.0019
# Epoch 21/100
# 3/3 [==============================] - 0s 164ms/step - loss: 0.0019
# Epoch 22/100
# 3/3 [==============================] - 0s 149ms/step - loss: 0.0018
# Epoch 23/100
# 3/3 [==============================] - 0s 165ms/step - loss: 0.0017
# Epoch 24/100
# 3/3 [==============================] - 0s 163ms/step - loss: 0.0015
# Epoch 25/100
# 3/3 [==============================] - 0s 160ms/step - loss: 0.0015
# Epoch 26/100
# 3/3 [==============================] - 0s 143ms/step - loss: 0.0015
# Epoch 27/100
# 3/3 [==============================] - 0s 153ms/step - loss: 0.0014
# Epoch 28/100
# 3/3 [==============================] - 0s 157ms/step - loss: 0.0013
# Epoch 29/100
# 3/3 [==============================] - 0s 157ms/step - loss: 0.0013
# Epoch 30/100
# 3/3 [==============================] - 1s 230ms/step - loss: 0.0012
# Epoch 31/100
# 3/3 [==============================] - 1s 177ms/step - loss: 0.0012
# Epoch 32/100
# 3/3 [==============================] - 1s 194ms/step - loss: 0.0011
# Epoch 33/100
# 3/3 [==============================] - 1s 177ms/step - loss: 0.0011
# Epoch 34/100
# 3/3 [==============================] - 1s 172ms/step - loss: 0.0010
# Epoch 35/100
# 3/3 [==============================] - 1s 173ms/step - loss: 9.9694e-04
# Epoch 36/100
# 3/3 [==============================] - 1s 172ms/step - loss: 9.5694e-04
# Epoch 37/100
# 3/3 [==============================] - 0s 166ms/step - loss: 9.2747e-04
# Epoch 38/100
# 3/3 [==============================] - 0s 165ms/step - loss: 8.8087e-04
# Epoch 39/100
# 3/3 [==============================] - 0s 138ms/step - loss: 8.5213e-04
# Epoch 40/100
# 3/3 [==============================] - 0s 148ms/step - loss: 8.1545e-04
# Epoch 41/100
# 3/3 [==============================] - 0s 139ms/step - loss: 7.8522e-04
# Epoch 42/100
# 3/3 [==============================] - 0s 148ms/step - loss: 7.5174e-04
# Epoch 43/100
# 3/3 [==============================] - 0s 143ms/step - loss: 7.2196e-04 0s - loss: 7.2196e-0
# Epoch 44/100
# 3/3 [==============================] - 0s 135ms/step - loss: 6.9296e-04
# Epoch 45/100
# 3/3 [==============================] - 0s 148ms/step - loss: 6.6785e-04
# Epoch 46/100
# 3/3 [==============================] - 0s 155ms/step - loss: 6.4848e-04
# Epoch 47/100
# 3/3 [==============================] - 0s 143ms/step - loss: 6.1418e-04
# Epoch 48/100
# 3/3 [==============================] - 0s 132ms/step - loss: 6.0123e-04
# Epoch 49/100
# 3/3 [==============================] - 0s 139ms/step - loss: 5.7560e-04
# Epoch 50/100
# 3/3 [==============================] - 0s 137ms/step - loss: 5.5552e-04
# Epoch 51/100
# 3/3 [==============================] - 0s 150ms/step - loss: 5.3492e-04
# Epoch 52/100
# 3/3 [==============================] - 1s 180ms/step - loss: 5.1477e-04
# Epoch 53/100
# 3/3 [==============================] - 0s 161ms/step - loss: 4.9762e-04
# Epoch 54/100
# 3/3 [==============================] - 0s 160ms/step - loss: 4.8169e-04
# Epoch 55/100
# 3/3 [==============================] - 0s 155ms/step - loss: 4.6579e-04
# Epoch 56/100
# 3/3 [==============================] - 0s 160ms/step - loss: 4.5317e-04
# Epoch 57/100
# 3/3 [==============================] - 0s 158ms/step - loss: 4.3999e-04
# Epoch 58/100
# 3/3 [==============================] - 0s 153ms/step - loss: 4.2932e-04
# Epoch 59/100
# 3/3 [==============================] - 0s 158ms/step - loss: 4.1813e-04
# Epoch 60/100
# 3/3 [==============================] - 0s 148ms/step - loss: 4.0316e-04
# Epoch 61/100
# 3/3 [==============================] - 0s 135ms/step - loss: 3.9508e-04
# Epoch 62/100
# 3/3 [==============================] - 0s 140ms/step - loss: 3.8572e-04
# Epoch 63/100
# 3/3 [==============================] - 0s 134ms/step - loss: 3.7721e-04
# Epoch 64/100
# 3/3 [==============================] - 0s 141ms/step - loss: 3.7085e-04
# Epoch 65/100
# 3/3 [==============================] - 0s 138ms/step - loss: 3.6107e-04
# Epoch 66/100
# 3/3 [==============================] - 0s 145ms/step - loss: 3.5357e-04
# Epoch 67/100
# 3/3 [==============================] - 0s 147ms/step - loss: 3.4743e-04 0s - loss: 3.4743e-0
# Epoch 68/100
# 3/3 [==============================] - 0s 138ms/step - loss: 3.3992e-04
# Epoch 69/100
# 3/3 [==============================] - 0s 157ms/step - loss: 3.3414e-04
# Epoch 70/100
# 3/3 [==============================] - 0s 154ms/step - loss: 3.3036e-04
# Epoch 71/100
# 3/3 [==============================] - 0s 142ms/step - loss: 3.2724e-04
# Epoch 72/100
# 3/3 [==============================] - 0s 140ms/step - loss: 3.2050e-04
# Epoch 73/100
# 3/3 [==============================] - 0s 147ms/step - loss: 3.1576e-04
# Epoch 74/100
# 3/3 [==============================] - 0s 143ms/step - loss: 3.0963e-04
# Epoch 75/100
# 3/3 [==============================] - 1s 167ms/step - loss: 3.0808e-04
# Epoch 76/100
# 3/3 [==============================] - 1s 210ms/step - loss: 3.0000e-04
# Epoch 77/100
# 3/3 [==============================] - 1s 174ms/step - loss: 2.9689e-04
# Epoch 78/100
# 3/3 [==============================] - 1s 174ms/step - loss: 2.9312e-04
# Epoch 79/100
# 3/3 [==============================] - 1s 167ms/step - loss: 2.8997e-04
# Epoch 80/100
# 3/3 [==============================] - 1s 173ms/step - loss: 2.8537e-04
# Epoch 81/100
# 3/3 [==============================] - 1s 171ms/step - loss: 2.8095e-04
# Epoch 82/100
# 3/3 [==============================] - 0s 166ms/step - loss: 2.7701e-04
# Epoch 83/100
# 3/3 [==============================] - 0s 159ms/step - loss: 2.7714e-04
# Epoch 84/100
# 3/3 [==============================] - 0s 135ms/step - loss: 2.7551e-04
# Epoch 85/100
# 3/3 [==============================] - 0s 140ms/step - loss: 2.7262e-04
# Epoch 86/100
# 3/3 [==============================] - 0s 165ms/step - loss: 2.6920e-04
# Epoch 87/100
# 3/3 [==============================] - 0s 135ms/step - loss: 2.6379e-04
# Epoch 88/100
# 3/3 [==============================] - 0s 140ms/step - loss: 2.6232e-04
# Epoch 89/100
# 3/3 [==============================] - 0s 135ms/step - loss: 2.6099e-04
# Epoch 90/100
# 3/3 [==============================] - 0s 143ms/step - loss: 2.5386e-04
# Epoch 91/100
# 3/3 [==============================] - 0s 153ms/step - loss: 2.5308e-04
# Epoch 92/100
# 3/3 [==============================] - 0s 153ms/step - loss: 2.4783e-04
# Epoch 93/100
# 3/3 [==============================] - 1s 172ms/step - loss: 2.4569e-04
# Epoch 94/100
# 3/3 [==============================] - 0s 144ms/step - loss: 2.4187e-04
# Epoch 95/100
# 3/3 [==============================] - 0s 153ms/step - loss: 2.3876e-04
# Epoch 96/100
# 3/3 [==============================] - 0s 147ms/step - loss: 2.3711e-04
# Epoch 97/100
# 3/3 [==============================] - 0s 153ms/step - loss: 2.3514e-04
# Epoch 98/100
# 3/3 [==============================] - 1s 195ms/step - loss: 2.3158e-04
# Epoch 99/100
# 3/3 [==============================] - 1s 191ms/step - loss: 2.2939e-04
# Epoch 100/100
# 3/3 [==============================] - 1s 204ms/step - loss: 2.2706e-04
# RMSE for feature 3 is: 0.0945409710690585
# Epoch 1/100
# 3/3 [==============================] - 1s 187ms/step - loss: 0.2757
# Epoch 2/100
# 3/3 [==============================] - 1s 188ms/step - loss: 0.1559
# Epoch 3/100
# 3/3 [==============================] - 1s 190ms/step - loss: 0.0997
# Epoch 4/100
# 3/3 [==============================] - 1s 200ms/step - loss: 0.0941
# Epoch 5/100
# 3/3 [==============================] - 1s 197ms/step - loss: 0.0609
# Epoch 6/100
# 3/3 [==============================] - 1s 206ms/step - loss: 0.0443
# Epoch 7/100
# 3/3 [==============================] - 1s 187ms/step - loss: 0.0244
# Epoch 8/100
# 3/3 [==============================] - 1s 193ms/step - loss: 0.0089
# Epoch 9/100
# 3/3 [==============================] - 0s 165ms/step - loss: 0.0040
# Epoch 10/100
# 3/3 [==============================] - 1s 263ms/step - loss: 0.0077
# Epoch 11/100
# 3/3 [==============================] - 1s 233ms/step - loss: 0.0073
# Epoch 12/100
# 3/3 [==============================] - 1s 226ms/step - loss: 0.0045
# Epoch 13/100
# 3/3 [==============================] - 1s 234ms/step - loss: 0.0012
# Epoch 14/100
# 3/3 [==============================] - 1s 211ms/step - loss: 0.0018
# Epoch 15/100
# 3/3 [==============================] - 1s 215ms/step - loss: 0.0023
# Epoch 16/100
# 3/3 [==============================] - 1s 171ms/step - loss: 0.0020
# Epoch 17/100
# 3/3 [==============================] - 0s 150ms/step - loss: 0.0016
# Epoch 18/100
# 3/3 [==============================] - 0s 156ms/step - loss: 7.2432e-04
# Epoch 19/100
# 3/3 [==============================] - 0s 144ms/step - loss: 7.4300e-04
# Epoch 20/100
# 3/3 [==============================] - 0s 148ms/step - loss: 6.8686e-04
# Epoch 21/100
# 3/3 [==============================] - 0s 144ms/step - loss: 8.3580e-04
# Epoch 22/100
# 3/3 [==============================] - 0s 150ms/step - loss: 6.1925e-04
# Epoch 23/100
# 3/3 [==============================] - 0s 161ms/step - loss: 5.2962e-04
# Epoch 24/100
# 3/3 [==============================] - 0s 151ms/step - loss: 4.4533e-04
# Epoch 25/100
# 3/3 [==============================] - 0s 146ms/step - loss: 5.0289e-04
# Epoch 26/100
# 3/3 [==============================] - 0s 140ms/step - loss: 4.5229e-04
# Epoch 27/100
# 3/3 [==============================] - 0s 145ms/step - loss: 4.2515e-04
# Epoch 28/100
# 3/3 [==============================] - 0s 147ms/step - loss: 3.7971e-04
# Epoch 29/100
# 3/3 [==============================] - 1s 189ms/step - loss: 3.7918e-04
# Epoch 30/100
# 3/3 [==============================] - 1s 187ms/step - loss: 3.6837e-04
# Epoch 31/100
# 3/3 [==============================] - 1s 172ms/step - loss: 3.5668e-04
# Epoch 32/100
# 3/3 [==============================] - 1s 174ms/step - loss: 3.3520e-04
# Epoch 33/100
# 3/3 [==============================] - 0s 157ms/step - loss: 3.2674e-04
# Epoch 34/100
# 3/3 [==============================] - 0s 166ms/step - loss: 3.1817e-04
# Epoch 35/100
# 3/3 [==============================] - 0s 164ms/step - loss: 3.1292e-04
# Epoch 36/100
# 3/3 [==============================] - 0s 164ms/step - loss: 3.0060e-04
# Epoch 37/100
# 3/3 [==============================] - 0s 144ms/step - loss: 2.9490e-04
# Epoch 38/100
# 3/3 [==============================] - 0s 138ms/step - loss: 2.8832e-04
# Epoch 39/100
# 3/3 [==============================] - 0s 137ms/step - loss: 2.8061e-04
# Epoch 40/100
# 3/3 [==============================] - 0s 139ms/step - loss: 2.7660e-04
# Epoch 41/100
# 3/3 [==============================] - 0s 140ms/step - loss: 2.6830e-04
# Epoch 42/100
# 3/3 [==============================] - 0s 136ms/step - loss: 2.6199e-04
# Epoch 43/100
# 3/3 [==============================] - 0s 140ms/step - loss: 2.5538e-04
# Epoch 44/100
# 3/3 [==============================] - 0s 143ms/step - loss: 2.5084e-04 0s - loss: 2.5084e-0
# Epoch 45/100
# 3/3 [==============================] - 0s 138ms/step - loss: 2.4491e-04
# Epoch 46/100
# 3/3 [==============================] - 0s 156ms/step - loss: 2.4116e-04
# Epoch 47/100
# 3/3 [==============================] - 0s 147ms/step - loss: 2.3648e-04
# Epoch 48/100
# 3/3 [==============================] - 0s 136ms/step - loss: 2.3275e-04 0s - loss: 2.3275e-0
# Epoch 49/100
# 3/3 [==============================] - 0s 152ms/step - loss: 2.2850e-04
# Epoch 50/100
# 3/3 [==============================] - 0s 131ms/step - loss: 2.2565e-04 0s - loss: 2.2565e-0
# Epoch 51/100
# 3/3 [==============================] - 0s 158ms/step - loss: 2.2160e-04
# Epoch 52/100
# 3/3 [==============================] - 1s 191ms/step - loss: 2.1940e-04
# Epoch 53/100
# 3/3 [==============================] - 0s 165ms/step - loss: 2.1650e-04
# Epoch 54/100
# 3/3 [==============================] - 0s 166ms/step - loss: 2.1286e-04
# Epoch 55/100
# 3/3 [==============================] - 0s 161ms/step - loss: 2.1109e-04
# Epoch 56/100
# 3/3 [==============================] - 1s 178ms/step - loss: 2.0993e-04
# Epoch 57/100
# 3/3 [==============================] - 1s 179ms/step - loss: 2.0686e-04
# Epoch 58/100
# 3/3 [==============================] - 1s 175ms/step - loss: 2.0499e-04
# Epoch 59/100
# 3/3 [==============================] - 1s 183ms/step - loss: 2.0241e-04
# Epoch 60/100
# 3/3 [==============================] - 0s 149ms/step - loss: 2.0110e-04
# Epoch 61/100
# 3/3 [==============================] - 0s 162ms/step - loss: 2.0061e-04
# Epoch 62/100
# 3/3 [==============================] - 1s 171ms/step - loss: 1.9733e-04
# Epoch 63/100
# 3/3 [==============================] - 0s 161ms/step - loss: 1.9587e-04
# Epoch 64/100
# 3/3 [==============================] - 0s 139ms/step - loss: 1.9421e-04
# Epoch 65/100
# 3/3 [==============================] - 0s 146ms/step - loss: 1.9337e-04
# Epoch 66/100
# 3/3 [==============================] - 0s 149ms/step - loss: 1.9202e-04
# Epoch 67/100
# 3/3 [==============================] - 0s 140ms/step - loss: 1.9149e-04
# Epoch 68/100
# 3/3 [==============================] - 0s 157ms/step - loss: 1.9081e-04
# Epoch 69/100
# 3/3 [==============================] - 0s 148ms/step - loss: 1.8899e-04
# Epoch 70/100
# 3/3 [==============================] - 0s 147ms/step - loss: 1.8838e-04
# Epoch 71/100
# 3/3 [==============================] - 0s 146ms/step - loss: 1.8757e-04
# Epoch 72/100
# 3/3 [==============================] - 0s 147ms/step - loss: 1.8681e-04
# Epoch 73/100
# 3/3 [==============================] - 0s 161ms/step - loss: 1.8578e-04
# Epoch 74/100
# 3/3 [==============================] - 1s 180ms/step - loss: 1.8491e-04
# Epoch 75/100
# 3/3 [==============================] - 1s 178ms/step - loss: 1.8460e-04
# Epoch 76/100
# 3/3 [==============================] - 1s 180ms/step - loss: 1.8328e-04
# Epoch 77/100
# 3/3 [==============================] - 0s 167ms/step - loss: 1.8287e-04
# Epoch 78/100
# 3/3 [==============================] - 1s 170ms/step - loss: 1.8283e-04
# Epoch 79/100
# 3/3 [==============================] - 0s 161ms/step - loss: 1.8152e-04
# Epoch 80/100
# 3/3 [==============================] - 1s 172ms/step - loss: 1.8131e-04
# Epoch 81/100
# 3/3 [==============================] - 1s 177ms/step - loss: 1.8063e-04
# Epoch 82/100
# 3/3 [==============================] - 0s 154ms/step - loss: 1.8022e-04
# Epoch 83/100
# 3/3 [==============================] - 0s 143ms/step - loss: 1.7985e-04
# Epoch 84/100
# 3/3 [==============================] - 0s 161ms/step - loss: 1.7909e-04
# Epoch 85/100
# 3/3 [==============================] - 0s 148ms/step - loss: 1.7906e-04
# Epoch 86/100
# 3/3 [==============================] - 0s 139ms/step - loss: 1.7804e-04
# Epoch 87/100
# 3/3 [==============================] - 0s 151ms/step - loss: 1.7847e-04
# Epoch 88/100
# 3/3 [==============================] - 0s 144ms/step - loss: 1.7808e-04
# Epoch 89/100
# 3/3 [==============================] - 0s 142ms/step - loss: 1.7824e-04
# Epoch 90/100
# 3/3 [==============================] - 0s 160ms/step - loss: 1.7695e-04
# Epoch 91/100
# 3/3 [==============================] - 0s 153ms/step - loss: 1.7753e-04
# Epoch 92/100
# 3/3 [==============================] - 0s 157ms/step - loss: 1.7818e-04
# Epoch 93/100
# 3/3 [==============================] - 0s 156ms/step - loss: 1.7706e-04
# Epoch 94/100
# 3/3 [==============================] - 0s 160ms/step - loss: 1.7701e-04
# Epoch 95/100
# 3/3 [==============================] - 0s 157ms/step - loss: 1.7630e-04
# Epoch 96/100
# 3/3 [==============================] - 1s 199ms/step - loss: 1.7461e-04
# Epoch 97/100
# 3/3 [==============================] - 1s 191ms/step - loss: 1.7498e-04
# Epoch 98/100
# 3/3 [==============================] - 1s 179ms/step - loss: 1.7752e-04
# Epoch 99/100
# 3/3 [==============================] - 1s 186ms/step - loss: 1.7632e-04
# Epoch 100/100
# 3/3 [==============================] - 1s 180ms/step - loss: 1.7540e-04
# RMSE for feature 4 is: 0.07785251909391373
# Epoch 1/100
# 3/3 [==============================] - 1s 176ms/step - loss: 0.1457
# Epoch 2/100
# 3/3 [==============================] - 1s 192ms/step - loss: 0.0694
# Epoch 3/100
# 3/3 [==============================] - 1s 192ms/step - loss: 0.0404
# Epoch 4/100
# 3/3 [==============================] - 1s 202ms/step - loss: 0.0384
# Epoch 5/100
# 3/3 [==============================] - 1s 189ms/step - loss: 0.0202
# Epoch 6/100
# 3/3 [==============================] - 0s 160ms/step - loss: 0.0211
# Epoch 7/100
# 3/3 [==============================] - 0s 165ms/step - loss: 0.0137
# Epoch 8/100
# 3/3 [==============================] - 1s 171ms/step - loss: 0.0117
# Epoch 9/100
# 3/3 [==============================] - 1s 231ms/step - loss: 0.0125
# Epoch 10/100
# 3/3 [==============================] - 1s 302ms/step - loss: 0.0101
# Epoch 11/100
# 3/3 [==============================] - 1s 253ms/step - loss: 0.0112
# Epoch 12/100
# 3/3 [==============================] - 1s 236ms/step - loss: 0.0098
# Epoch 13/100
# 3/3 [==============================] - 1s 247ms/step - loss: 0.0094
# Epoch 14/100
# 3/3 [==============================] - 1s 231ms/step - loss: 0.0089
# Epoch 15/100
# 3/3 [==============================] - 1s 186ms/step - loss: 0.0081
# Epoch 16/100
# 3/3 [==============================] - 0s 156ms/step - loss: 0.0082
# Epoch 17/100
# 3/3 [==============================] - 1s 173ms/step - loss: 0.0078
# Epoch 18/100
# 3/3 [==============================] - 1s 206ms/step - loss: 0.0076
# Epoch 19/100
# 3/3 [==============================] - 0s 156ms/step - loss: 0.0072
# Epoch 20/100
# 3/3 [==============================] - 0s 155ms/step - loss: 0.0068
# Epoch 21/100
# 3/3 [==============================] - 0s 161ms/step - loss: 0.0065
# Epoch 22/100
# 3/3 [==============================] - 0s 160ms/step - loss: 0.0061
# Epoch 23/100
# 3/3 [==============================] - 0s 141ms/step - loss: 0.0059
# Epoch 24/100
# 3/3 [==============================] - 0s 147ms/step - loss: 0.0055
# Epoch 25/100
# 3/3 [==============================] - 0s 146ms/step - loss: 0.0052
# Epoch 26/100
# 3/3 [==============================] - 0s 153ms/step - loss: 0.0048
# Epoch 27/100
# 3/3 [==============================] - 1s 189ms/step - loss: 0.0044
# Epoch 28/100
# 3/3 [==============================] - 1s 187ms/step - loss: 0.0040
# Epoch 29/100
# 3/3 [==============================] - 1s 190ms/step - loss: 0.0036
# Epoch 30/100
# 3/3 [==============================] - 1s 170ms/step - loss: 0.0031
# Epoch 31/100
# 3/3 [==============================] - 1s 178ms/step - loss: 0.0027
# Epoch 32/100
# 3/3 [==============================] - 1s 172ms/step - loss: 0.0022
# Epoch 33/100
# 3/3 [==============================] - 0s 165ms/step - loss: 0.0017
# Epoch 34/100
# 3/3 [==============================] - 1s 170ms/step - loss: 0.0013
# Epoch 35/100
# 3/3 [==============================] - 0s 141ms/step - loss: 8.2045e-04
# Epoch 36/100
# 3/3 [==============================] - 0s 137ms/step - loss: 4.8028e-04 0s - loss: 4.8028e-0
# Epoch 37/100
# 3/3 [==============================] - 0s 142ms/step - loss: 2.6004e-04
# Epoch 38/100
# 3/3 [==============================] - 0s 144ms/step - loss: 2.0299e-04
# Epoch 39/100
# 3/3 [==============================] - 0s 140ms/step - loss: 2.4175e-04
# Epoch 40/100
# 3/3 [==============================] - 0s 138ms/step - loss: 2.9978e-04
# Epoch 41/100
# 3/3 [==============================] - 0s 142ms/step - loss: 2.8892e-04
# Epoch 42/100
# 3/3 [==============================] - 0s 145ms/step - loss: 2.4685e-04
# Epoch 43/100
# 3/3 [==============================] - 0s 149ms/step - loss: 2.0718e-04
# Epoch 44/100
# 3/3 [==============================] - 0s 152ms/step - loss: 1.8508e-04
# Epoch 45/100
# 3/3 [==============================] - 0s 142ms/step - loss: 1.8084e-04
# Epoch 46/100
# 3/3 [==============================] - 0s 145ms/step - loss: 1.7276e-04
# Epoch 47/100
# 3/3 [==============================] - 0s 136ms/step - loss: 1.5865e-04
# Epoch 48/100
# 3/3 [==============================] - 0s 143ms/step - loss: 1.5536e-04
# Epoch 49/100
# 3/3 [==============================] - 0s 164ms/step - loss: 1.4691e-04
# Epoch 50/100
# 3/3 [==============================] - 1s 208ms/step - loss: 1.4043e-04
# Epoch 51/100
# 3/3 [==============================] - 1s 181ms/step - loss: 1.3995e-04
# Epoch 52/100
# 3/3 [==============================] - 1s 180ms/step - loss: 1.3659e-04
# Epoch 53/100
# 3/3 [==============================] - 1s 182ms/step - loss: 1.3634e-04
# Epoch 54/100
# 3/3 [==============================] - 1s 168ms/step - loss: 1.3396e-04
# Epoch 55/100
# 3/3 [==============================] - 0s 162ms/step - loss: 1.3530e-04
# Epoch 56/100
# 3/3 [==============================] - 0s 159ms/step - loss: 1.2989e-04
# Epoch 57/100
# 3/3 [==============================] - 0s 154ms/step - loss: 1.2680e-04
# Epoch 58/100
# 3/3 [==============================] - 0s 135ms/step - loss: 1.2287e-04 0s - loss: 1.2287e-0
# Epoch 59/100
# 3/3 [==============================] - 0s 131ms/step - loss: 1.1916e-04
# Epoch 60/100
# 3/3 [==============================] - 0s 141ms/step - loss: 1.1978e-04
# Epoch 61/100
# 3/3 [==============================] - 0s 139ms/step - loss: 1.1766e-04
# Epoch 62/100
# 3/3 [==============================] - 0s 138ms/step - loss: 1.1702e-04
# Epoch 63/100
# 3/3 [==============================] - 0s 135ms/step - loss: 1.1711e-04
# Epoch 64/100
# 3/3 [==============================] - 0s 130ms/step - loss: 1.1292e-04
# Epoch 65/100
# 3/3 [==============================] - 0s 146ms/step - loss: 1.1304e-04 0s - loss: 1.1304e-0
# Epoch 66/100
# 3/3 [==============================] - 0s 140ms/step - loss: 1.1174e-04
# Epoch 67/100
# 3/3 [==============================] - 0s 138ms/step - loss: 1.0982e-04
# Epoch 68/100
# 3/3 [==============================] - 0s 152ms/step - loss: 1.0899e-04
# Epoch 69/100
# 3/3 [==============================] - 0s 139ms/step - loss: 1.0843e-04
# Epoch 70/100
# 3/3 [==============================] - 0s 158ms/step - loss: 1.0816e-04
# Epoch 71/100
# 3/3 [==============================] - 0s 158ms/step - loss: 1.0990e-04
# Epoch 72/100
# 3/3 [==============================] - 1s 170ms/step - loss: 1.0978e-04
# Epoch 73/100
# 3/3 [==============================] - 1s 185ms/step - loss: 1.0801e-04
# Epoch 74/100
# 3/3 [==============================] - 0s 167ms/step - loss: 1.0412e-04
# Epoch 75/100
# 3/3 [==============================] - 1s 171ms/step - loss: 1.0374e-04
# Epoch 76/100
# 3/3 [==============================] - 0s 163ms/step - loss: 1.0570e-04
# Epoch 77/100
# 3/3 [==============================] - 0s 162ms/step - loss: 1.0228e-04
# Epoch 78/100
# 3/3 [==============================] - 0s 149ms/step - loss: 1.0638e-04
# Epoch 79/100
# 3/3 [==============================] - 0s 159ms/step - loss: 1.0105e-04
# Epoch 80/100
# 3/3 [==============================] - 0s 160ms/step - loss: 1.0091e-04
# Epoch 81/100
# 3/3 [==============================] - 0s 133ms/step - loss: 9.9922e-05
# Epoch 82/100
# 3/3 [==============================] - 0s 154ms/step - loss: 9.9687e-05
# Epoch 83/100
# 3/3 [==============================] - 0s 157ms/step - loss: 9.9340e-05
# Epoch 84/100
# 3/3 [==============================] - 0s 148ms/step - loss: 9.9707e-05
# Epoch 85/100
# 3/3 [==============================] - 0s 146ms/step - loss: 9.9953e-05
# Epoch 86/100
# 3/3 [==============================] - 0s 142ms/step - loss: 1.0058e-04
# Epoch 87/100
# 3/3 [==============================] - 0s 146ms/step - loss: 9.8261e-05
# Epoch 88/100
# 3/3 [==============================] - 0s 139ms/step - loss: 9.8555e-05 0s - loss: 1.0060e-
# Epoch 89/100
# 3/3 [==============================] - 0s 156ms/step - loss: 9.6298e-05
# Epoch 90/100
# 3/3 [==============================] - 0s 135ms/step - loss: 9.6053e-05
# Epoch 91/100
# 3/3 [==============================] - 0s 142ms/step - loss: 9.5058e-05
# Epoch 92/100
# 3/3 [==============================] - 0s 143ms/step - loss: 9.5858e-05
# Epoch 93/100
# 3/3 [==============================] - 0s 147ms/step - loss: 9.8344e-05
# Epoch 94/100
# 3/3 [==============================] - 0s 150ms/step - loss: 9.5315e-05
# Epoch 95/100
# 3/3 [==============================] - 1s 175ms/step - loss: 9.3831e-05
# Epoch 96/100
# 3/3 [==============================] - 1s 212ms/step - loss: 9.3544e-05
# Epoch 97/100
# 3/3 [==============================] - 0s 165ms/step - loss: 9.2999e-05
# Epoch 98/100
# 3/3 [==============================] - 1s 169ms/step - loss: 9.5276e-05
# Epoch 99/100
# 3/3 [==============================] - 0s 166ms/step - loss: 9.3947e-05
# Epoch 100/100
# 3/3 [==============================] - 1s 172ms/step - loss: 9.4554e-05
# RMSE for feature 5 is: 0.03407737860619234
#                 x             y             z      x_vv      y_vv      z_vv
# 0   -37941.770471  -2902.683601  17459.093164 -0.194413 -2.848353 -1.045913
# 1   -36316.112147 -17309.400968  10937.045485  0.811158 -2.567289 -1.431098
# 2   -29778.312304 -29359.311458   2900.330289  1.695884 -1.944849 -1.616080
# 3   -19205.347840 -37426.440772  -5516.696596  2.349087 -1.069410 -1.579981
# 4    -5978.463570 -40443.193592 -13124.514992  2.690605 -0.054256 -1.330607
# ..            ...           ...           ...       ...       ...       ...
# 195  37949.565766  21215.179701  -7548.238526 -1.004034  2.335823  1.750202
# 196  30795.454840  31558.660726   1867.509886 -1.850410  1.652212  1.820702
# 197  19927.832386  37751.941360  11111.367272 -2.444773  0.739197  1.646685
# 198   6729.441634  39037.401194  18850.614631 -2.703945 -0.278398  1.243372
# 199  -7048.594603  35271.414016  23929.684171 -2.591031 -1.260681  0.656485
#
# [200 rows x 6 columns]

# %% [markdown]
# ### Compare and plot results/errors SEPARATELY

# %%
train_size = int(len(df) * 0.8) 

test_df = df[train_size:]
train_df = df[:train_size]

test_df
# Out:
#                 x             y             z      x_vv      y_vv      z_vv
# 800 -38640.279625  -2764.935183  17604.980941 -0.242379 -2.869481 -1.032661
# 801 -37222.004154 -17134.306183  11135.984105  0.783117 -2.603604 -1.431914
# 802 -30699.416577 -29154.049729   3087.546466  1.701144 -1.974296 -1.633559
# 803 -19981.800403 -37148.488205  -5420.909441  2.380643 -1.071344 -1.607049
# 804  -6568.003292 -40025.406603 -13203.492438  2.729043 -0.025797 -1.357603
# ..            ...           ...           ...       ...       ...       ...
# 995  38132.961517  21370.880108  -7532.333000 -0.876644  2.199413  1.750026
# 996  31399.515894  31233.289707   1828.575655 -1.692745  1.562118  1.820311
# 997  20906.077447  37238.565267  10967.804062 -2.312211  0.726117  1.664753
# 998   7871.245318  38575.122415  18731.818721 -2.661184 -0.221639  1.293445
# 999  -6142.526530  34919.272230  24066.202237 -2.681132 -1.179765  0.734721
#
# [200 rows x 6 columns]

# %%
df_pred.index=test_df.index

# %%
for feature in list(test_df.columns):
    
    plt.figure(figsize=(16,8))

    plt.plot(train_df[feature])
    plt.plot(test_df[feature])
    plt.plot(df_pred[feature])

    plt.title(f'Feature {feature}')
    plt.xlabel('Time', fontsize=18)
    plt.ylabel('Coord [m]', fontsize=18)
    plt.legend(['Train', 'Test', 'Predictions'], loc='lower right')
    plt.show()

# %%
# ABSOLUTE ERRORS:

for feature in list(test_df.columns):
    
    plt.figure(figsize=(16,8))

    plt.plot(abs(df_pred[feature]-test_df[feature])/max(test_df[feature]))

    plt.title(f'Feature {feature} absolute error plot:')
    plt.xlabel('Time', fontsize=18)
    plt.ylabel('Absolute Error [/]', fontsize=18)
    plt.show()

# %%
# RELATIVE ERRORS

for feature in list(test_df.columns):
    
    plt.figure(figsize=(16,8))

    plt.plot(abs(df_pred[feature]-test_df[feature])/test_df[feature])

    plt.title(f'Feature {feature} relative error plot:')
    plt.xlabel('Time', fontsize=18)
    plt.ylabel('Relative Error [/]', fontsize=18)
    plt.show()

# %% [markdown]
# ## Compare and Plot 3D trajectories/errors:

# %% [markdown]
# ### 1. For 3D Position coordinates

# %%
fig = plt.figure()
plt.figure(figsize=(50,20))

plt.axes(projection="3d")
x_line = df_pred['x']
y_line = df_pred['y']
z_line = df_pred['z']
plt.plot(x_line, y_line, z_line, 'red')

x_line2 = test_df['x']
y_line2 = test_df['y']
z_line2 = test_df['z']
plt.plot(x_line2, y_line2, z_line2, 'yellow')

plt.legend(['Predictions', 'Test'], loc='lower right')
plt.show()

# %% [markdown]
# ### 2. For 3D velocity coordinates

# %%
fig = plt.figure()
plt.figure(figsize=(50,20))

plt.axes(projection="3d")
x_line = df_pred['x_vv']
y_line = df_pred['y_vv']
z_line = df_pred['z_vv']
plt.plot(x_line, y_line, z_line, 'red')

x_line2 = test_df['x_vv']
y_line2 = test_df['y_vv']
z_line2 = test_df['z_vv']
plt.plot(x_line2, y_line2, z_line2, 'yellow')

plt.legend(['Predictions', 'Test'], loc='lower right')
plt.show()

# %% [markdown]
# ### Trying to make better/interactive plots :)

# %%
from plotly import __version__
# %matplotlib inline
import cufflinks as cf
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
import plotly.graph_objects as go
import plotly.io as pio

init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
fig = plt.figure()
plt.figure(figsize=(50,20))

plt.axes(projection="3d")
x_line = df_pred['x']
y_line = df_pred['y']
z_line = df_pred['z']
plt.iplot(x_line, y_line, z_line, 'red')

x_line2 = test_df['x']
y_line2 = test_df['y']
z_line2 = test_df['z']
plt.iplot(x_line2, y_line2, z_line2, 'yellow')

plt.legend(['Predictions', 'Test'], loc='lower right')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-61-1ab1a0cd95cd> in <module>
# ----> 1 fig = pio.figure()
#       2 plt.figure(figsize=(50,20))
#       3
#       4 plt.axes(projection="3d")
#       5 x_line = df_pred['x']
#
# ~\anaconda3\envs\poliastro\lib\site-packages\_plotly_utils\importers.py in __getattr__(import_name)
#      39         raise AttributeError(
#      40             "module {__name__!r} has no attribute {name!r}".format(
# ---> 41                 name=import_name, __name__=parent_name
#      42             )
#      43         )
#
# AttributeError: module 'plotly.io' has no attribute 'figure'

# %%
import plotly.express as px

fig = px.line_3d(df_pred, x="x", y="y", z="z")
fig = px.line_3d(test_df, x="x", y="y", z="z")
fig.show()
# Out:
# <div>                            <div id="8f05866e-9bd9-493e-b0c1-2258b288cbaf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8f05866e-9bd9-493e-b0c1-2258b288cbaf")) {                    Plotly.newPlot(                        "8f05866e-9bd9-493e-b0c1-2258b288cbaf",                        [{"hovertemplate": "x=%{x}<br>y=%{y}<br>z=%{z}<extra></extra>", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "scene": "scene", "showlegend": false, "type": "scatter3d", "x": ["x_test", "x_pred"], "y": ["y_test", "y_pred"], "z": ["z_test", "z_pred"]}],                        {"legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "scene": {"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "xaxis": {"title": {"text": "x"}}, "yaxis": {"title": {"text": "y"}}, "zaxis": {"title": {"text": "z"}}}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh ...

# %%
# Init empty predictions DF
df_plot = pd.DataFrame(columns=['x_test', 'y_test', 'z_test', 'x_pred', 'y_pred', 'z_pred'])

df_plot.x_test=test_df.x
df_plot.y_test=test_df.y
df_plot.z_test=test_df.z

df_plot.x_pred=df_pred.x
df_plot.y_pred=df_pred.y
df_plot.z_pred=df_pred.z

df_plot
# Out:
#            x_test        y_test        z_test        x_pred        y_pred  \
# 800 -38640.279625  -2764.935183  17604.980941 -37941.770471  -2902.683601
# 801 -37222.004154 -17134.306183  11135.984105 -36316.112147 -17309.400968
# 802 -30699.416577 -29154.049729   3087.546466 -29778.312304 -29359.311458
# 803 -19981.800403 -37148.488205  -5420.909441 -19205.347840 -37426.440772
# 804  -6568.003292 -40025.406603 -13203.492438  -5978.463570 -40443.193592
# ..            ...           ...           ...           ...           ...
# 995  38132.961517  21370.880108  -7532.333000  37949.565766  21215.179701
# 996  31399.515894  31233.289707   1828.575655  30795.454840  31558.660726
# 997  20906.077447  37238.565267  10967.804062  19927.832386  37751.941360
# 998   7871.245318  38575.122415  18731.818721   6729.441634  39037.401194
# 999  -6142.526530  34919.272230  24066.202237  -7048.594603  35271.414016
#
#            z_pred
# 800  17459.093164
# 801  10937.045485
# 802   2900.330289
# 803  -5516.696596
# 804 -13124.514992
# ..            ...
# 995  -7548.238526
# 996   1867.509886
# 997  11111.367272
# 998  18850.614631
# 999  23929.684171
#
# [200 rows x 6 columns]
